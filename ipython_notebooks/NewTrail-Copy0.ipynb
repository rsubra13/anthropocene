# %%
import anthropocene.readers as rd
from anthropocene.classes import Paper,KeyPaper
dir_papers = rd.wos.from_dir("/Users/Ramki/Documents/ramki")
dir_papers
# Out:
# wos_data type <type 'list'>
# [{'atitle': 'ZOOPLANKTON SPECIES ASSOCIATIONS IN QUEBEC LAKES - VARIATION WITH ABIOTIC FACTORS, INCLUDING NATURAL AND ANTHROPOGENIC ACIDIFICATION',
#   'date': '1990',
#   'doi': '10.1139/f90-011',
#   'jtitle': 'CANADIAN JOURNAL OF FISHERIES AND AQUATIC SCIENCES',
#   'keywords': None,
#   'wosid': 'WOS:A1990CG69300011'},
#  {'atitle': 'EVALUATION OF BUFFER CAPACITY OF FRESH-WATER ECOSYSTEMS WITH RESPECT TO THE ANTHROPOGENIC ACIDIFICATION',
#   'date': '1994',
#   'doi': None,
#   'jtitle': 'DOKLADY AKADEMII NAUK SSSR',
#   'keywords': ['Anthropocene',
#    ' Climate changes',
#    ' Climate CHANGES',
#    ' Production objectives',
#    ' Borana',
#    ' Ethiopia',
#    'Ethiopia',
#    'Ethiopia'],
#   'wosid': 'WOS:A1990EM04300055'},
#  {'atitle': 'LECHATELIER PRINCIPLE AND THE RESPONSE OF BIOTA ON THE ANTHROPOGENIC DISTURBANCE OF THE CARBON-CYCLE',
#   'date': '1990',
#   'doi': None,
#   'jtitle': 'DOKLADY AKADEMII NAUK SSSR',
#   'keywords': None,
#   'wosid': 'WOS:A1990DJ36100060'},
#  {'atitle': 'BURIED GLACIAL DEPRESSIONS OF ANTHROPOGENIC AGE IN THE TERRITORY OF THE UKRAINIAN SSR',
#   'date': '1990',
#   'doi': None,
#   'jtitle': 'DOPOVIDI AKADEMII NAUK UKRAINSKOI RSR SERIYA B-GEOLOGICHNI KHIMICHNI TA BIOLOGICHNI NAUKI',
#   'keywords': ['Anthropocene',
#    ' Climate changes',
#    ' Climate CHANGES',
#    ' Production objectives',
#    ' Borana',
#    ' Ethiopia',
#    'Ethiopia',
#    'Ethiopia'],
#   'wosid': 'WOS:A1990DQ96600005'},
#  {'atitle': 'Livestock Diversification: an Adaptive Strategy to Climate and Rangeland Ecosystem Changes in Southern Ethiopia',
#   'date': '2014',
#   'doi': '10.1007/s10745-014-9668-2',
#   'jtitle': 'HUMAN ECOLOGY',
#   'keywords': ['Adaptation',
#    ' Environmental changes',
#    ' Multispecies herding',
#    ' Production objectives',
#    ' Borana',
#    ' Ethiopia',
#    'Ethiopia',
#    'Ethiopia'],
#   'wosid': 'WOS:000340494800001'},
#  {'atitle': 'Decline of Birch Woodland Cover in Ajrsardalur Iceland from 1587 to 1938',
#   'date': '2014',
#   'doi': '10.1007/s10745-014-9670-8',
#   'jtitle': 'HUMAN ECOLOGY',
#   'keywords': ['Deforestation',
#    ' Soil erosion',
#    ' Land ownership',
#    ' GIS',
#    ' Historical maps'],
#   'wosid': 'WOS:000340494800006'},
#  {'atitle': 'PROXIMATE COMPOSITION AND NUTRIENT ELEMENTS IN THE UNUSUAL ALGAL JELLIES OF LAKE OGUTA IN SOUTHERN NIGERIA',
#   'date': '1990',
#   'doi': '10.1002/iroh.19900750310',
#   'jtitle': 'INTERNATIONALE REVUE DER GESAMTEN HYDROBIOLOGIE',
#   'keywords': ['WEST AFRICA',
#    ' FRESH-WATER',
#    ' ALGAL JELLIES',
#    ' PROXIMATE CONSTITUENTS',
#    ' NUTRIENT ELEMENTS',
#    'Ethiopia',
#    'Ethiopia',
#    'Ethiopia',
#    'Anthropocene',
#    ' Climate changes',
#    ' Climate CHANGES',
#    ' Production objectives',
#    ' Borana',
#    ' Ethiopia',
#    'Ethiopia',
#    'Ethiopia'],
#   'wosid': 'WOS:A1990FK77300009'}]

# %%
# December 1

# Initialize to avoid overwriting
keywords_list = []
side_list=[]
main_list = [] 
main_dict ={}


keywords_list_new = []
side_list_new=[]
main_list_new = [] 
main_dict ={}



# This loop runs for each paper
for r in dir_papers:
    if r['keywords']:
        #print "################################Keywords::" , r['keywords'] , r['date']
        ### Make the lists empty to avoid overwriting
        keywords_list = []
        side_list=[]
        main_list_new = [] 
        
        # New dict
        keywords_list_new = []
        side_list_new=[]
        main_list = [] 
        
        paper = KeyPaper()
        ### This loop runs for each each keyword of a paper
        for each_kw in r['keywords']:
            print "paper", paper
            each_kw = each_kw.strip().lower() # convert to lowercase, even if it is not.
            try:
                main_dict[r['date']][0].keys() # to direct it to main_dict
                if r['date'] in main_dict.keys():
                    lst = [item.keys() for item in main_dict[r['date']]]
                    for i in lst:
                            for j in i:
                                if j not in side_list:
                                    side_list.append(j)
                    if any(each_kw in st for st in lst):
                        print "##ALREADY"
                        kw_index = side_list.index(each_kw)
                        #main_dict[r['date']][kw_index][each_kw] += 1
                        main_dict_new[r['date']][kw_index][each_kw] += 1
                        #print "cool*************" ,main_dict[r['date']] 
                    
                    else:
                       #print "##else"
                        new_dict={}
                        new_dict[each_kw] = 1
                        main_dict[r['date']].append(new_dict)
                        #print "main dict here$$$$$$$ " , main_dict
                        #print "herererrerer" , main_dict[r['date']]      
                           
            except:
                #print "except",main_dict
                keywords_dict={}
                side_list=[]
                keywords_dict[each_kw] = 1
                keywords_list.append(keywords_dict)
                main_dict[r['date']]= keywords_list  
                #print "keywords_dict" , keywords_dict , "keywords_list", keywords_list
                #print "maindict in except" , main_dict
# Out:
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY
# paper {'date': None, 'count': None, 'keywords': None}
# ##ALREADY

# %%
main_dict
# Out:
# {'1990': [{'anthropocene': 2},
#   {'climate changes': 4},
#   {'production objectives': 2},
#   {'borana': 2},
#   {'ethiopia': 9},
#   {'west africa': 1},
#   {'fresh-water': 1},
#   {'algal jellies': 1},
#   {'proximate constituents': 1},
#   {'nutrient elements': 1}],
#  '1994': [{'anthropocene': 1},
#   {'climate changes': 2},
#   {'production objectives': 1},
#   {'borana': 1},
#   {'ethiopia': 3}],
#  '2014': [{'adaptation': 1},
#   {'environmental changes': 1},
#   {'multispecies herding': 1},
#   {'production objectives': 1},
#   {'borana': 1},
#   {'ethiopia': 3},
#   {'deforestation': 1},
#   {'soil erosion': 1},
#   {'land ownership': 1},
#   {'gis': 1},
#   {'historical maps': 1}]}
