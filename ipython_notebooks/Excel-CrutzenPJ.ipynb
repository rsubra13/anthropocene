# %%
import anthropocene.readers as rd
from anthropocene.classes import Paper,KeyPaper
dir_papers = rd.wos.from_dir("/Users/Ramki/Desktop/Anthropocene/Anthropocene Files/CrutzenPJ")
#dir_papers
dir_papers
# Out:
# wos_data type <type 'list'>
# [{'atitle': 'Global and regional impacts of HONO on the chemical composition of clouds and aerosols',
#   'date': '2014',
#   'doi': '10.5194/acp-14-1167-2014',
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000332384900003'},
#  {'atitle': 'Perspectives on our planet in the Anthropocene',
#   'date': '2013',
#   'doi': '10.1071/EN13061',
#   'jtitle': 'ENVIRONMENTAL CHEMISTRY',
#   'keywords': None,
#   'wosid': 'WOS:000323645000002'},
#  {'atitle': 'Planetary Opportunities: A Social Contract for Global Change Science to Contribute to a Sustainable Future',
#   'date': '2012',
#   'doi': '10.1525/bio.2012.62.6.11',
#   'jtitle': 'BIOSCIENCE',
#   'keywords': ['assessments',
#    ' ecology',
#    ' sustainability',
#    ' interdisciplinary science',
#    ' policy',
#    ' ethics'],
#   'wosid': 'WOS:000305262500011'},
#  {'atitle': 'Global agriculture and nitrous oxide emissions',
#   'date': '2012',
#   'doi': '10.1038/NCLIMATE1458',
#   'jtitle': 'NATURE CLIMATE CHANGE',
#   'keywords': None,
#   'wosid': 'WOS:000305051600019'},
#  {'atitle': "The role of N2O derived from crop-based biofuels, and from agriculture in general, in Earth's climate",
#   'date': '2012',
#   'doi': '10.1098/rstb.2011.0313',
#   'jtitle': 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY B-BIOLOGICAL SCIENCES',
#   'keywords': ['nitrous oxide',
#    ' biofuels',
#    ' reactive N',
#    ' agriculture',
#    ' N2O emission factor',
#    ' life cycle analysis'],
#   'wosid': 'WOS:000302125400002'},
#  {'atitle': 'The role of carbonyl sulphide as a source of stratospheric sulphate aerosol and its impact on climate',
#   'date': '2012',
#   'doi': '10.5194/acp-12-1239-2012',
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000300656500003'},
#  {'atitle': 'Ozone perturbation from medium-size asteroid impacts in the ocean',
#   'date': '2010',
#   'doi': '10.1016/j.epsl.2010.08.036',
#   'jtitle': 'EARTH AND PLANETARY SCIENCE LETTERS',
#   'keywords': ['oceanic impact',
#    ' Near-Earth-Object',
#    ' modeling',
#    ' ozone perturbation',
#    ' atmospheric chemistry'],
#   'wosid': 'WOS:000284751200001'},
#  {'atitle': 'Anthropocene man',
#   'date': '2010',
#   'doi': None,
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:000282898700009'},
#  {'atitle': 'Climate Change and the Integrity of Science',
#   'date': '2010',
#   'doi': None,
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000277357100011'},
#  {'atitle': 'Nitrous oxide from aquaculture',
#   'date': '2010',
#   'doi': '10.1038/ngeo804',
#   'jtitle': 'NATURE GEOSCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000274974700003'},
#  {'atitle': 'Will climate change increase ozone depletion from low-energy-electron precipitation?',
#   'date': '2010',
#   'doi': '10.5194/acp-10-9647-2010',
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000283066300027'},
#  {'atitle': 'Formic acid above the Jungfraujoch during 1985-2007: observed variability, seasonality, but no long-term background evolution',
#   'date': '2010',
#   'doi': '10.5194/acp-10-10047-2010',
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000283663000024'},
#  {'atitle': 'Learning about ozone depletion',
#   'date': '2008',
#   'doi': '10.1007/s10584-008-9400-6',
#   'jtitle': 'CLIMATIC CHANGE',
#   'keywords': None,
#   'wosid': 'WOS:000257369600008'},
#  {'atitle': 'Exploring the geoengineering of climate using stratospheric sulfate aerosols: The role of particle size',
#   'date': '2008',
#   'doi': '10.1029/2007GL032179',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000252751900003'},
#  {'atitle': 'N2O release from agro-biofuel production negates global warming reduction by replacing fossil fuels',
#   'date': '2008',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000253908100015'},
#  {'atitle': 'The Anthropocene: Are humans now overwhelming the great forces of nature',
#   'date': '2007',
#   'doi': '10.1579/0044-7447(2007)36[614:TAAHNO]2.0.CO;2',
#   'jtitle': 'AMBIO',
#   'keywords': None,
#   'wosid': 'WOS:000251979900001'},
#  {'atitle': 'Stratospheric dryness: model simulations and satellite observations',
#   'date': '2007',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000244712400001'},
#  {'atitle': 'Two-years of NO3 radical observations in the boundary layer over the Eastern Mediterranean',
#   'date': '2007',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000243747600001'},
#  {'atitle': 'A climatic control on the accretion of meteoric and super-chondritic iridium-platinum to the Antarctic ice cap',
#   'date': '2006',
#   'doi': '10.1016/j.epsl.2006.08.015',
#   'jtitle': 'EARTH AND PLANETARY SCIENCE LETTERS',
#   'keywords': ['iridium',
#    ' platinum',
#    ' meteoric smoke',
#    ' ice',
#    ' Antarctica',
#    ' climate'],
#   'wosid': 'WOS:000242195100004'},
#  {'atitle': "Impacts of China's air pollution",
#   'date': '2006',
#   'doi': None,
#   'jtitle': 'FRONTIERS IN ECOLOGY AND THE ENVIRONMENT',
#   'keywords': None,
#   'wosid': 'WOS:000240642500003'},
#  {'atitle': 'Albedo enhancement by stratospheric sulfur injections: A contribution to resolve a policy dilemma?',
#   'date': '2006',
#   'doi': '10.1007/s10584-006-9101-y',
#   'jtitle': 'CLIMATIC CHANGE',
#   'keywords': None,
#   'wosid': 'WOS:000240307600001'},
#  {'atitle': 'Solar variability and planetary climates - Foreword',
#   'date': '2006',
#   'doi': '10.1007/s11214-006-9041-x',
#   'jtitle': 'SPACE SCIENCE REVIEWS',
#   'keywords': None,
#   'wosid': 'WOS:000244449400001'},
#  {'atitle': 'Formation of HNO3 and NO3- in the anthropogenically-influenced eastern Mediterranean marine boundary layer',
#   'date': '2006',
#   'doi': '10.1029/2005GL025069',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000236269600003'},
#  {'atitle': 'Emissions of major gaseous and particulate species during experimental burns of southern African biomass',
#   'date': '2006',
#   'doi': '10.1029/2005JD006319',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000235966700002'},
#  {'atitle': 'Interannual variability of stratospheric and tropospheric ozone determined from satellite measurements',
#   'date': '2005',
#   'doi': '10.1029/2005JD005868',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000233106500003'},
#  {'atitle': 'Earth system analysis for sustainability',
#   'date': '2005',
#   'doi': '10.3200/ENVT.47.8.10-25',
#   'jtitle': 'ENVIRONMENT',
#   'keywords': None,
#   'wosid': 'WOS:000232190200004'},
#  {'atitle': 'Oxygenated compounds in aged biomass burning plumes over the Eastern Mediterranean: evidence for strong secondary production of methanol and acetone',
#   'date': '2005',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000226449200001'},
#  {'atitle': 'Satellite measurements of NO2 from international shipping emissions',
#   'date': '2004',
#   'doi': '10.1029/2004GL020822',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000225878900001'},
#  {'atitle': 'Impact of reactive bromine chemistry in the troposphere',
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000225600400003'},
#  {'atitle': 'Emissions of ozone-depleting substances in Russia during 2001',
#   'date': '2004',
#   'doi': '10.1029/2004JD004633',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['ozone-depleting substances', ' emissions', ' Russia'],
#   'wosid': 'WOS:000223189800004'},
#  {'atitle': 'New Directions: The growing urban heat and pollution "island" effect - impact on chemistry and climate',
#   'date': '2004',
#   'doi': '10.1016/j.atmosenv.2004.03.032',
#   'jtitle': 'ATMOSPHERIC ENVIRONMENT',
#   'keywords': None,
#   'wosid': 'WOS:000221838100017'},
#  {'atitle': 'A late change to the programme',
#   'date': '2004',
#   'doi': '10.1038/429349a',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:000221644600019'},
#  {'atitle': 'Model study of multiphase DMS oxidation with a focus on halogens',
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000220844200001'},
#  {'atitle': "Abrupt changes: The Achilles' heels of the Earth System",
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'ENVIRONMENT',
#   'keywords': None,
#   'wosid': 'WOS:000220349300003'},
#  {'atitle': 'New insights in the global cycle of acetonitrile: release from the ocean and dry deposition in the tropical savanna of Venezuela',
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000188822700003'},
#  {'atitle': 'Halogen cycling and aerosol pH in the Hawaiian marine boundary layer',
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000188776100001'},
#  {'atitle': 'Role of the NO3 radicals in oxidation processes in the eastern Mediterranean troposphere during the MINOS campaign',
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000188776100002'},
#  {'atitle': 'Tropospheric ozone over a tropical Atlantic station in the Northern hemisphere: Paramaribo, Surinam',
#   'date': '2004',
#   'doi': '10.1111/j.1600-0889.2004.00083.x',
#   'jtitle': 'TELLUS SERIES B-CHEMICAL AND PHYSICAL METEOROLOGY',
#   'keywords': None,
#   'wosid': 'WOS:000189085300002'},
#  {'atitle': 'Comment on "Reactions at interfaces as a source of sulfate formation in sea-salt particles" (II)',
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000188530800022'},
#  {'atitle': 'Comprehensive laboratory measurements of biomass-burning emissions: 2. First intercomparison of open-path FTIR, PTR-MS, and GC- MS/FID/ECD',
#   'date': '2004',
#   'doi': '10.1029/2003JD003874',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['instrument intercomparision',
#    ' biomass burning',
#    ' oxygenated organic compounds'],
#   'wosid': 'WOS:000188867100002'},
#  {'atitle': 'Trace gas transport in the 1999/2000 Arctic winter: comparison of nudged GCM runs with observations',
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000188775400003'},
#  {'atitle': 'Sensitivities in global scale modeling of isoprene',
#   'date': '2004',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000188775100001'},
#  {'atitle': 'A model for studies of tropospheric ozone and nonmethane hydrocarbons: Model evaluation of ozone-related species',
#   'date': '2003',
#   'doi': '10.1029/2002JD003348',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['model evaluation',
#    ' nonmethane hydrocarbons',
#    ' ozone precursors'],
#   'wosid': 'WOS:000187490800001'},
#  {'atitle': 'The parasol effect on climate',
#   'date': '2003',
#   'doi': None,
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000186970100018'},
#  {'atitle': 'Comprehensive laboratory measurements of biomass-burning emissions: 1. Emissions from Indonesian, African, and other fuels',
#   'date': '2003',
#   'doi': '10.1029/2003JD003704',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['biomass burning',
#    ' oxygenated organic compounds',
#    ' Indonesian fires'],
#   'wosid': 'WOS:000187483200002'},
#  {'atitle': 'How long have we been in the Anthropocene era? Comment',
#   'date': '2003',
#   'doi': '10.1023/B:CLIM.0000004708.74871.62',
#   'jtitle': 'CLIMATIC CHANGE',
#   'keywords': None,
#   'wosid': 'WOS:000186660900001'},
#  {'atitle': 'Rarity of upper-tropospheric low O-3 mixing ratio events during MOZAIC flights',
#   'date': '2003',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000185623000002'},
#  {'atitle': 'Inorganic bromine in the marine boundary layer: a critical review',
#   'date': '2003',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000185238800001'},
#  {'atitle': 'New directions: Atmospheric brown "Clouds"',
#   'date': '2003',
#   'doi': '10.1016/S1352-2310(03)00536-3',
#   'jtitle': 'ATMOSPHERIC ENVIRONMENT',
#   'keywords': None,
#   'wosid': 'WOS:000184721600012'},
#  {'atitle': 'Characterization of carbonaceous aerosols outflow from India and Arabia: Biomass/biofuel burning and fossil fuel combustion',
#   'date': '2003',
#   'doi': '10.1029/2002JD003277',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['aerosol chemical characterization',
#    ' biomass burning',
#    ' fossil fuel combustion'],
#   'wosid': 'WOS:000184868300006'},
#  {'atitle': 'A new interactive chemistry-climate model: 1. Present-day climatology and interannual variability of the middle atmosphere using the model and 9 years of HALOE/UARS data',
#   'date': '2003',
#   'doi': '10.1029/2002JD002971',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['chemistry-climate model',
#    ' stratospheric ozone',
#    ' UARS satellite data',
#    ' chlorine partitioning',
#    ' polar ozone'],
#   'wosid': 'WOS:000183103300011'},
#  {'atitle': 'A model for studies of tropospheric ozone and nonmethane hydrocarbons: Model description and ozone results',
#   'date': '2003',
#   'doi': '10.1029/2002JD002893',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['global model',
#    ' ozone budget',
#    ' tropospheric ozone',
#    ' stratosphere-troposphere exchange',
#    ' nonmethane hydrocarbons',
#    ' mass-wind inconsistency'],
#   'wosid': 'WOS:000183103300008'},
#  {'atitle': 'Wavelength dependence of isotope fractionation in N2O photolysis',
#   'date': '2003',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000181716900001'},
#  {'atitle': 'Global chemical weather forecasts for field campaign planning: predictions and observations of large-scale features during MINOS, CONTRACE, and INDOEX',
#   'date': '2003',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000181185800001'},
#  {'atitle': 'Modeling the chemical effects of ship exhaust in the cloud-free marine boundary layer',
#   'date': '2003',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000181091600001'},
#  {'atitle': 'A discussion on the determination of atmospheric OH and its trends',
#   'date': '2003',
#   'doi': None,
#   'jtitle': 'ATMOSPHERIC CHEMISTRY AND PHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:000180854800001'},
#  {'atitle': 'Comment on "Cloud condensation nuclei in the Amazon Basin: "Marine" conditions over a continent?", by G. C. Roberts et al.',
#   'date': '2003',
#   'doi': '10.1029/2002GL015206',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000182892600001'},
#  {'atitle': 'The "anthropocene"',
#   'date': '2002',
#   'doi': '10.1051/jp4:20020447',
#   'jtitle': 'JOURNAL DE PHYSIQUE IV',
#   'keywords': None,
#   'wosid': 'WOS:000180633400002'},
#  {'atitle': 'Electrical discharge source for tropospheric "ozone-rich transients\'\'',
#   'date': '2002',
#   'doi': '10.1029/2002JD002345',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['tropospheric ozone budget',
#    ' electricity induced trace gas production',
#    ' stratosphere-to-troposphere ozone'],
#   'wosid': 'WOS:000180867500037'},
#  {'atitle': 'The Indian Ocean Experiment and the Asian Brown Cloud',
#   'date': '2002',
#   'doi': None,
#   'jtitle': 'CURRENT SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000178967800014'},
#  {'atitle': 'Global air pollution crossroads over the Mediterranean',
#   'date': '2002',
#   'doi': '10.1126/science.1075457',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000178791200050'},
#  {'atitle': 'Absorbing mediterranean aerosols lead to a large reduction in the solar radiation at the surface',
#   'date': '2002',
#   'doi': '10.1029/2002GL015767',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000180607700029'},
#  {'atitle': 'Diurnal cycles and seasonal variation of isoprene and its oxidation products in the tropical savanna atmosphere',
#   'date': '2002',
#   'doi': '10.1029/2001GB001421',
#   'jtitle': 'GLOBAL BIOGEOCHEMICAL CYCLES',
#   'keywords': ['PTR-MS',
#    ' savanna',
#    ' isoprene oxidation',
#    ' biogenic emissions'],
#   'wosid': 'WOS:000180874100022'},
#  {'atitle': 'Bromide content of sea-salt aerosol particles collected over the Indian Ocean during INDOEX 1999',
#   'date': '2002',
#   'doi': '10.1029/2001JD001133',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['bromine',
#    ' aerosol',
#    ' marine boundary layer',
#    ' INDOEX',
#    ' leaded fuel'],
#   'wosid': 'WOS:000180428300083'},
#  {'atitle': 'Air mass classification during the INDOEX R/V Ronald Brown cruise using measurements of nonmethane hydrocarbons, CH4, CO2, CO, (CO)-C-14, and delta O-18(CO)',
#   'date': '2002',
#   'doi': '10.1029/2001JD000730',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['INDOEX',
#    ' Indian Ocean',
#    ' NMHC',
#    ' isotopes',
#    ' air mass classification',
#    ' long-range transport'],
#   'wosid': 'WOS:000180428300015'},
#  {'atitle': 'Modeling halogen chemistry in the marine boundary layer - 2. Interactions with sulfur and the cloud-covered MBL',
#   'date': '2002',
#   'doi': '10.1029/2001JD000943',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['sea-salt aerosol',
#    ' cloud chemistry',
#    ' halogen chemistry',
#    ' bromine',
#    ' chlorine',
#    ' sulfur-halogen interactions'],
#   'wosid': 'WOS:000180427200003'},
#  {'atitle': 'Modeling halogen chemistry in the marine boundary layer - 1. Cloud-free MBL',
#   'date': '2002',
#   'doi': '10.1029/2001JD000942',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['sea-salt aerosol',
#    ' O-3 destruction',
#    ' aerosol chemistry',
#    ' iodine',
#    ' bromine',
#    ' chlorine'],
#   'wosid': 'WOS:000180427200021'},
#  {'atitle': 'Organic trace gas measurements by PTR-MS during INDOEX 1999',
#   'date': '2002',
#   'doi': '10.1029/2001JD000576',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['INDOEX',
#    ' PTR-MS',
#    ' VOCs',
#    ' biomass burning',
#    ' acetone',
#    ' acetonitrile'],
#   'wosid': 'WOS:000180428300018'},
#  {'atitle': 'Budgets of O-3 and CO in the upper troposphere: CARIBIC passenger aircraft results 1997-2001',
#   'date': '2002',
#   'doi': '10.1029/2001JD001529',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000180427200017'},
#  {'atitle': 'Near equatorial CO and O-3 profiles over the Indian Ocean during the winter monsoon: High O-3 levels in the middle troposphere and interhemispheric exchange',
#   'date': '2002',
#   'doi': '10.1029/2001JD001126',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['Intertropical Convergence Zone',
#    ' carbon monoxide',
#    ' ozone',
#    ' relative humidity',
#    ' stratosphere-troposphere exchange',
#    ' tropical cyclone',
#    ' convection',
#    ' interhemispheric exchange'],
#   'wosid': 'WOS:000180372700005'},
#  {'atitle': 'Trace gas measurements along the Trans-Siberian railroad: The TROICA 5 expedition',
#   'date': '2002',
#   'doi': '10.1029/2001JD000953',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['tropospheric chemistry',
#    ' boundary layer',
#    ' wetlands',
#    ' Russia',
#    ' Siberia',
#    ' Trans-Siberian railroad'],
#   'wosid': 'WOS:000178977300023'},
#  {'atitle': 'Are CH2O measurements in the marine boundary layer suitable for testing the current understanding of CH4 photooxidation?: A model study',
#   'date': '2002',
#   'doi': '10.1029/2001JD000722',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': ['formaldehyde',
#    ' CH2O',
#    ' HCHO',
#    ' troposphere',
#    ' marine boundary layer',
#    ' budget'],
#   'wosid': 'WOS:000178890100006'},
#  {'atitle': 'Geology of mankind',
#   'date': '2002',
#   'doi': '10.1038/415023a',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:000173028800020'},
#  {'atitle': 'The effects of industrial and agricultural practices on atmospheric chemistry and climate during the anthropocene',
#   'date': '2002',
#   'doi': '10.1081/ESE-120003224',
#   'jtitle': 'JOURNAL OF ENVIRONMENTAL SCIENCE AND HEALTH PART A-TOXIC/HAZARDOUS SUBSTANCES & ENVIRONMENTAL ENGINEERING',
#   'keywords': None,
#   'wosid': 'WOS:000175759400002'},
#  {'atitle': 'Atmosphere - Aerosols, climate, and the hydrological cycle',
#   'date': '2001',
#   'doi': '10.1126/science.1064034',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000172647700039'},
#  {'atitle': 'Special section: Indian Ocean Experiment (INDOEX), Part 1 - Foreword',
#   'date': '2001',
#   'doi': '10.1029/2001JD900172',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000172355800025'},
#  {'atitle': 'Indian Ocean Experiment: An integrated analysis of the climate forcing and effects of the great Indo-Asian haze',
#   'date': '2001',
#   'doi': '10.1029/2001JD900133',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000172355800026'},
#  {'atitle': 'Variability-lifetime relationship of VOCs observed at the Sonnblick Observatory 1999 - estimation of HO-densities',
#   'date': '2001',
#   'doi': '10.1016/S1352-2310(01)00341-7',
#   'jtitle': 'ATMOSPHERIC ENVIRONMENT',
#   'keywords': None,
#   'wosid': 'WOS:000171913300006'},
#  {'atitle': 'Isotopic enrichment of nitrous oxide ((NNO)-N-15-N-14, (NNO)-N-14-N-15, (NNO)-N-14-N-14-O-18) in the stratosphere and in the laboratory',
#   'date': '2001',
#   'doi': '10.1029/2000JD900822',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000168839900021'},
#  {'atitle': 'Ground based gas phase measurements in Surinam during the LBA-Claire 98 experiment',
#   'date': '2001',
#   'doi': '10.1023/A:1010762209008',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['LBA-Claire',
#    ' atmospheric tropical photochemistry',
#    ' tropical forest',
#    ' ozone',
#    ' hydrogenperoxide',
#    ' gaseous organic acids'],
#   'wosid': 'WOS:000168190200002'},
#  {'atitle': 'On a fundamental problem in implementing flux-form advection schemes for tracer transport in 3-dimensional general circulation and chemistry transport models',
#   'date': '2001',
#   'doi': '10.1256/smsqj.57317',
#   'jtitle': 'QUARTERLY JOURNAL OF THE ROYAL METEOROLOGICAL SOCIETY',
#   'keywords': ['flux-form advection',
#    ' mass-wind inconsistency',
#    ' 3-D model',
#    ' tracer transport'],
#   'wosid': 'WOS:000168500000017'},
#  {'atitle': 'Catalysis by NOx as the main cause of the spring to fall stratospheric ozone decline in the northern hemisphere',
#   'date': '2001',
#   'doi': '10.1021/jp001984h',
#   'jtitle': 'JOURNAL OF PHYSICAL CHEMISTRY A',
#   'keywords': None,
#   'wosid': 'WOS:000167268600022'},
#  {'atitle': 'The Indian Ocean Experiment: Widespread air pollution from South and Southeast Asia',
#   'date': '2001',
#   'doi': '10.1126/science.1057103',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000166860100042'},
#  {'atitle': 'The origin of the anomalous or "mass-independent" oxygen isotope fractionation in tropospheric N2O',
#   'date': '2001',
#   'doi': '10.1029/2000GL012295',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000166581700026'},
#  {'atitle': 'High concentrations of reactive biogenic VOCs at a high altitude site in late autumn',
#   'date': '2001',
#   'doi': '10.1029/2000GL012255',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000166581700027'},
#  {'atitle': 'High acetone concentrations throughout the 0-12 km altitude range over the tropical rainforest in Surinam',
#   'date': '2001',
#   'doi': '10.1023/A:1006370600615',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['acetone',
#    ' tropical rainforest emissions',
#    ' proton-transfer reaction mass spectrometry',
#    ' carbon monoxide',
#    ' acetonitrile',
#    ' 2-propanol',
#    ' biomass burning',
#    ' Surinam'],
#   'wosid': 'WOS:000166865500001'},
#  {'atitle': 'An atmospheric chemistry interpretation of mass scans obtained from a proton transfer mass spectrometer flown over the tropical rainforest of Surinam',
#   'date': '2001',
#   'doi': '10.1023/A:1006322701523',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['proton transfer mass spectrometer (PTR-MS)',
#    ' tropical rainforest emissions',
#    ' volatile organic compounds (VOC)',
#    ' isoprene',
#    ' isoprene oxidation products',
#    ' methacrolein',
#    ' methyl vinyl ketone',
#    ' upper tropospheric HO(x)',
#    ' tropical OH',
#    ' acetonitrile',
#    ' acetone'],
#   'wosid': 'WOS:000166865500002'},
#  {'atitle': 'Isoprene and its oxidation products methyl vinyl ketone, methacrolein, and isoprene related peroxides measured online over the tropical rain forest of Surinam in March 1998',
#   'date': '2001',
#   'doi': '10.1023/A:1006326802432',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['isoprene',
#    ' isoprene oxidation products',
#    ' tropical forest boundary layer',
#    ' box model',
#    ' methylvinylketone',
#    ' methacrolein'],
#   'wosid': 'WOS:000166865500003'},
#  {'atitle': 'Human impacts on atmospheric chemisty',
#   'date': '2001',
#   'doi': '10.1146/annurev.earth.29.1.17',
#   'jtitle': 'ANNUAL REVIEW OF EARTH AND PLANETARY SCIENCES',
#   'keywords': ['anthropogenic activities',
#    ' effects on the atmosphere',
#    ' stratospheric ozone depletion',
#    ' photochemical ozone production',
#    ' ozone hole',
#    ' CH4',
#    ' NOx',
#    ' CO',
#    ' HOx',
#    ' ClOx'],
#   'wosid': 'WOS:000168810800002'},
#  {'atitle': 'The ascent of atmospheric sciences (vol 290, pg 299, 2000)',
#   'date': '2000',
#   'doi': None,
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000165228200027'},
#  {'atitle': 'The ascent of atmospheric sciences',
#   'date': '2000',
#   'doi': None,
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000089818100035'},
#  {'atitle': 'Comment on "A chemical aqueous phase radical mechanism for tropospheric chemistry" by H. Herrmann et al.',
#   'date': '2000',
#   'doi': '10.1016/S0045-6535(99)00541-X',
#   'jtitle': 'CHEMOSPHERE',
#   'keywords': None,
#   'wosid': 'WOS:000086998300001'},
#  {'atitle': 'Development and intercomparison of condensed isoprene oxidation mechanisms for global atmospheric modeling',
#   'date': '2000',
#   'doi': '10.1023/A:1006391009798',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['isoprene oxidation',
#    ' global atmospheric modeling',
#    ' condensed chemical mechanism'],
#   'wosid': 'WOS:000088031400002'},
#  {'atitle': 'The impact of precipitation scavenging on the transport of trace gases: A 3-dimensional model sensitivity study',
#   'date': '2000',
#   'doi': '10.1023/A:1006322926426',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['precipitation scavenging',
#    " Henry's Lawdependence",
#    ' global model study',
#    ' convection',
#    ' gasrejection on freezing',
#    ' trace gas vertical transport'],
#   'wosid': 'WOS:000088031400004'},
#  {'atitle': 'Variability-lifetime relationship for organic trace gases: A novel aid to compound identification and estimation of HO concentrations',
#   'date': '2000',
#   'doi': '10.1029/2000JD900203',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000089107600003'},
#  {'atitle': 'Emissions of volatile organic compounds from Quercus ilex L. measured by Proton Transfer Reaction Mass Spectrometry under different environmental conditions',
#   'date': '2000',
#   'doi': '10.1029/2000JD900296',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000089107600010'},
#  {'atitle': 'Significance of HOx and peroxides production due to alkene ozonolysis during fall and winter: A modeling study',
#   'date': '2000',
#   'doi': '10.1029/2000JD900074',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000088368700004'},
#  {'atitle': 'Impact of non-methane hydrocarbons on tropospheric chemistry and the oxidizing power of the global troposphere: 3-dimensional modelling results',
#   'date': '2000',
#   'doi': '10.1023/A:1006300616544',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['non-methane hydrocarbons',
#    ' ozone',
#    ' HOx',
#    ' CO',
#    ' NOx',
#    ' tropospheric chemistry',
#    ' global',
#    ' 3-d modeling',
#    ' upper troposphere'],
#   'wosid': 'WOS:000086111300003'},
#  {'atitle': 'NOx-catalyzed ozone destruction and NOx activation at midlatitudes to high latitudes as the main cause of the spring to fall ozone decline in the Northern Hemisphere',
#   'date': '2000',
#   'doi': '10.1029/2000JD900069',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000087366600005'},
#  {'atitle': 'Measurement of the isotopic fractionation of (NNO)-N-15-N-14-O-16, (NNO)-N-14-N-15-O-16 and (NNO)-N-14-N-14-O-18 in the UV photolysis of nitrous oxide',
#   'date': '2000',
#   'doi': '10.1029/1999GL011135',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000086748600041'},
#  {'atitle': 'Human-activity-enhanced formation of organic aerosols by biogenic hydrocarbon oxidation',
#   'date': '2000',
#   'doi': '10.1029/1999JD901148',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000086586400027'},
#  {'atitle': 'Budget of ozone in the stratosphere.',
#   'date': '2000',
#   'doi': None,
#   'jtitle': 'ABSTRACTS OF PAPERS OF THE AMERICAN CHEMICAL SOCIETY',
#   'keywords': None,
#   'wosid': 'WOS:000087246201521'},
#  {'atitle': 'Inverse modeling of the global CO cycle 1. Inversion of CO mixing ratios',
#   'date': '2000',
#   'doi': '10.1029/1999JD900818',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000085086400004'},
#  {'atitle': 'Inverse modeling of the global CO cycle 2. Inversion of C-13/C-12 and O-18/O-16 isotope ratios',
#   'date': '2000',
#   'doi': '10.1029/1999JD900819',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000085086400005'},
#  {'atitle': 'Comment on "Methane photooxidation in the atmosphere: Contrast between two methods of analysis" by Harold Johnston and Douglas Kinnison',
#   'date': '2000',
#   'doi': None,
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000084856600009'},
#  {'atitle': 'Comparison between global chemistry transport model results and Measurement of Ozone and Water Vapor by Airbus In-Service Aircraft (MOZAIC) data',
#   'date': '2000',
#   'doi': '10.1029/1999JD900474',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000084856600016'},
#  {'atitle': 'Identification of extratropical two-way troposphere-stratosphere mixing based on CARIBIC measurements of O-3, CO, and ultrafine particles',
#   'date': '2000',
#   'doi': '10.1029/1999JD900759',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000084856600017'},
#  {'atitle': 'High spatial and temporal resolution measurements of primary organics and their oxidation products over the tropical forests of Surinam',
#   'date': '2000',
#   'doi': '10.1016/S1352-2310(99)00482-3',
#   'jtitle': 'ATMOSPHERIC ENVIRONMENT',
#   'keywords': ['proton transfer mass spectrometer (PTR-MS)',
#    ' tropical rainforest emissions',
#    ' volatile organic compounds (VOC)',
#    ' isoprene',
#    ' isoprene oxidation products',
#    ' methacrolein',
#    ' methyl vinyl ketone',
#    ' upper tropospheric HO(x)',
#    ' acetone'],
#   'wosid': 'WOS:000085908400001'},
#  {'atitle': 'Acetone and PAN in the upper troposphere: impact on ozone production from aircraft emissions',
#   'date': '2000',
#   'doi': '10.1016/S1352-2310(00)00159-X',
#   'jtitle': 'ATMOSPHERIC ENVIRONMENT',
#   'keywords': ['aircraft NO emissions',
#    ' NMHC',
#    ' photochemical model',
#    ' hydroxyl',
#    ' upper tropospheric ozone',
#    ' acetone',
#    ' PAN'],
#   'wosid': 'WOS:000088749000008'},
#  {'atitle': 'Actinic fluxes and photodissociation coefficients in cloud fields embedded in realistic atmospheres',
#   'date': '1999',
#   'doi': '10.1029/1999JD900748',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000084399500007'},
#  {'atitle': 'Production of boundary layer ozone from tropical American Savannah biomass burning emissions',
#   'date': '1999',
#   'doi': '10.1016/S1352-2310(99)00301-5',
#   'jtitle': 'ATMOSPHERIC ENVIRONMENT',
#   'keywords': ['ozone',
#    ' CO',
#    ' biomass burning',
#    ' tropical savannah',
#    ' ozone production ratio'],
#   'wosid': 'WOS:000084153800001'},
#  {'atitle': 'The global effects of Asian haze',
#   'date': '1999',
#   'doi': '10.1109/6.809124',
#   'jtitle': 'IEEE SPECTRUM',
#   'keywords': None,
#   'wosid': 'WOS:000084034200015'},
#  {'atitle': 'A model for studies of tropospheric photochemistry: Description, global distributions, and evaluation',
#   'date': '1999',
#   'doi': '10.1029/1999JD900425',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000083781200014'},
#  {'atitle': 'Influence of NOx emissions from ships on tropospheric photochemistry and climate',
#   'date': '1999',
#   'doi': '10.1038/46013',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:000083716400045'},
#  {'atitle': 'CO emissions from degrading plant matter (I). Measurements',
#   'date': '1999',
#   'doi': '10.1034/j.1600-0889.1999.t01-4-00003.x',
#   'jtitle': 'TELLUS SERIES B-CHEMICAL AND PHYSICAL METEOROLOGY',
#   'keywords': None,
#   'wosid': 'WOS:000083803500003'},
#  {'atitle': 'CO emissions from degrading plant matter (II). Estimate of a global source strength',
#   'date': '1999',
#   'doi': '10.1034/j.1600-0889.1999.t01-4-00004.x',
#   'jtitle': 'TELLUS SERIES B-CHEMICAL AND PHYSICAL METEOROLOGY',
#   'keywords': None,
#   'wosid': 'WOS:000083803500004'},
#  {'atitle': 'CARIBIC - Civil aircraft for global measurement of trace gases and aerosols in the tropopause region',
#   'date': '1999',
#   'doi': '10.1175/1520-0426(1999)016<1373:CCAFGM>2.0.CO;2',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC AND OCEANIC TECHNOLOGY',
#   'keywords': None,
#   'wosid': 'WOS:000082958500010'},
#  {'atitle': 'The upper stratospheric ozone budget: An update of calculations based on HALOE data',
#   'date': '1999',
#   'doi': '10.1023/A:1006290927549',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['upper stratosphere',
#    ' ozone budget',
#    ' ozone deficit problem',
#    ' HALOE'],
#   'wosid': 'WOS:000082480000001'},
#  {'atitle': 'Analysis of the CEPEX ozone data using a 3D chemistry-meteorology model',
#   'date': '1999',
#   'doi': '10.1256/smsqj.56009',
#   'jtitle': 'QUARTERLY JOURNAL OF THE ROYAL METEOROLOGICAL SOCIETY',
#   'keywords': ['convection',
#    ' Equatorial Pacific',
#    ' global modelling',
#    ' ozone',
#    ' tropics'],
#   'wosid': 'WOS:000083597400009'},
#  {'atitle': 'Ozone in the remote marine boundary layer: A possible role for halogens',
#   'date': '1999',
#   'doi': '10.1029/1999JD900023',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000082690200013'},
#  {'atitle': 'The role of BrNO3 in marine tropospheric chemistry: A model study',
#   'date': '1999',
#   'doi': '10.1029/1999GL900478',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000082680300020'},
#  {'atitle': 'Kinetics and products of the reactions BrO+DMS and Br+DMS at 298 K',
#   'date': '1999',
#   'doi': '10.1021/jp9905979',
#   'jtitle': 'JOURNAL OF PHYSICAL CHEMISTRY A',
#   'keywords': None,
#   'wosid': 'WOS:000082571000009'},
#  {'atitle': 'Parameters for global ecosystem models',
#   'date': '1999',
#   'doi': '10.1038/21098',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:000080778400038'},
#  {'atitle': 'Biomass burning as a source of formaldehyde, acetaldehyde, methanol, acetone, acetonitrile, and hydrogen cyanide',
#   'date': '1999',
#   'doi': '10.1029/1999GL900156',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000079793700040'},
#  {'atitle': 'Arctic ozone loss due to denitrification',
#   'date': '1999',
#   'doi': '10.1126/science.283.5410.2064',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000079369800040'},
#  {'atitle': 'Chemical ozone loss in the Arctic vortex in the winter 1995-96: HALOE measurements in conjunction with other observations (vol 16, pg 101, 1999)',
#   'date': '1999',
#   'doi': None,
#   'jtitle': 'ANNALES GEOPHYSICAE-ATMOSPHERES HYDROSPHERES AND SPACE SCIENCES',
#   'keywords': None,
#   'wosid': 'WOS:000079386200012'},
#  {'atitle': 'Acetone, methanol, and other partially oxidized volatile organic emissions from dead plant matter by abiological processes: Significance for atmospheric HOx chemistry',
#   'date': '1999',
#   'doi': '10.1029/98GB02428',
#   'jtitle': 'GLOBAL BIOGEOCHEMICAL CYCLES',
#   'keywords': None,
#   'wosid': 'WOS:000079003000002'},
#  {'atitle': 'Iodine chemistry and its role in halogen activation and ozone loss in the marine boundary layer: A model study',
#   'date': '1999',
#   'doi': '10.1023/A:1006179901037',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['aerosol',
#    ' iodine chemistry',
#    ' halogen chemistry',
#    ' marine boundary layer',
#    ' modeling',
#    ' ozone loss',
#    ' sea salt'],
#   'wosid': 'WOS:000079565200004'},
#  {'atitle': 'Short-term variations in the C-13/C-12 ratio of CO as a measure of Cl activation during tropospheric ozone depletion events in the Arctic',
#   'date': '1999',
#   'doi': '10.1029/1998JD100020',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000078188700009'},
#  {'atitle': 'Chemical ozone loss in the Arctic vortex in the winter 1995-96: HALOE measurements in conjunction with other observations',
#   'date': '1999',
#   'doi': '10.1007/s005850050740',
#   'jtitle': 'ANNALES GEOPHYSICAE-ATMOSPHERES HYDROSPHERES AND SPACE SCIENCES',
#   'keywords': ['chemical ozone loss (Arctic vortex 1995-96',
#    ' halogen chemistry)'],
#   'wosid': 'WOS:000077901500011'},
#  {'atitle': 'On the background photochemistry of tropospheric ozone',
#   'date': '1999',
#   'doi': '10.1034/j.1600-0889.1999.00010.x',
#   'jtitle': 'TELLUS SERIES A-DYNAMIC METEOROLOGY AND OCEANOGRAPHY',
#   'keywords': None,
#   'wosid': 'WOS:000079223700010'},
#  {'atitle': 'Budgets of fixed nitrogen in the Orinoco savannah region: Role of pyrodenitrification',
#   'date': '1998',
#   'doi': '10.1029/98GB02314',
#   'jtitle': 'GLOBAL BIOGEOCHEMICAL CYCLES',
#   'keywords': None,
#   'wosid': 'WOS:000077533900009'},
#  {'atitle': 'FTIR studies on lifetime prolongation of stratospheric ice particles due to NAT coating',
#   'date': '1998',
#   'doi': '10.1029/1998GL900040',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000076839800006'},
#  {'atitle': 'Global distribution of atmospheric bromine-monoxide from GOME on earth observing satellite ERS-2',
#   'date': '1998',
#   'doi': '10.1029/98GL02417',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:000075462000019'},
#  {'atitle': 'Mass-independent oxygen isotope fractionation in atmospheric CO as a result of the reaction CO+OH',
#   'date': '1998',
#   'doi': '10.1126/science.281.5376.544',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000075012300035'},
#  {'atitle': 'How the atmosphere keeps itself clean and how this is affected by human activities',
#   'date': '1998',
#   'doi': '10.1351/pac199870071319',
#   'jtitle': 'PURE AND APPLIED CHEMISTRY',
#   'keywords': None,
#   'wosid': 'WOS:000076607300002'},
#  {'atitle': 'Fluxes of CO(2), CH(4) and N(2)O from a temperate forest soil: the effects of leaves and humus layers',
#   'date': '1998',
#   'doi': '10.1034/j.1600-0889.1998.t01-2-00003.x',
#   'jtitle': 'TELLUS SERIES B-CHEMICAL AND PHYSICAL METEOROLOGY',
#   'keywords': None,
#   'wosid': 'WOS:000074745400003'},
#  {'atitle': 'The impact of cloud particle gravitational settling on soluble trace gas distributions',
#   'date': '1998',
#   'doi': '10.1034/j.1600-0889.1998.t01-2-00005.x',
#   'jtitle': 'TELLUS SERIES B-CHEMICAL AND PHYSICAL METEOROLOGY',
#   'keywords': None,
#   'wosid': 'WOS:000074745400005'},
#  {'atitle': 'Isotope analysis based source identification for atmospheric CH4 and CO sampled across Russia using the Trans-Siberian railroad',
#   'date': '1998',
#   'doi': '10.1029/97JD03738',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000073172100002'},
#  {'atitle': 'Changing concentration, lifetime and climate forcing of atmospheric methane',
#   'date': '1998',
#   'doi': '10.1034/j.1600-0889.1998.t01-1-00002.x',
#   'jtitle': 'TELLUS SERIES B-CHEMICAL AND PHYSICAL METEOROLOGY',
#   'keywords': None,
#   'wosid': 'WOS:000073415200002'},
#  {'atitle': 'Paul J Crutzen - Director Max-Planck-Institute for Chemistry and Nobel Prize Winner',
#   'date': '1998',
#   'doi': None,
#   'jtitle': 'CHEMISTRY & INDUSTRY',
#   'keywords': None,
#   'wosid': 'WOS:000072680600021'},
#  {'atitle': 'Aerosol pH in the marine boundary layer: A review and model evaluation',
#   'date': '1998',
#   'doi': '10.1016/S0021-8502(97)10011-8',
#   'jtitle': 'JOURNAL OF AEROSOL SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:000072878700009'},
#  {'atitle': 'An efficient method for online calculations of photolysis and heating rates',
#   'date': '1998',
#   'doi': '10.1175/1520-0469(1998)055<0863:AEMFOC>2.0.CO;2',
#   'jtitle': 'JOURNAL OF THE ATMOSPHERIC SCIENCES',
#   'keywords': None,
#   'wosid': 'WOS:000072288400012'},
#  {'atitle': 'High-latitude, summertime NOx activation and seasonal ozone decline in the lower stratosphere: Model calculations based on observations by HALOE on UARS',
#   'date': '1998',
#   'doi': '10.1029/97JD03078',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000072148300020'},
#  {'atitle': 'Development of a chemistry module for GCMs: first results of a multiannual integration',
#   'date': '1998',
#   'doi': '10.1007/s00585-998-0205-8',
#   'jtitle': 'ANNALES GEOPHYSICAE-ATMOSPHERES HYDROSPHERES AND SPACE SCIENCES',
#   'keywords': ['atmospheric composition and structure',
#    ' middle atmosphere',
#    ' meteorology and atmospheric dynamics',
#    ' climatology',
#    ' general circulation'],
#   'wosid': 'WOS:000072444800011'},
#  {'atitle': 'Trace gas measurements between Moscow and Vladivostok using the Trans-Siberian Railroad',
#   'date': '1998',
#   'doi': '10.1023/A:1005848202970',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': ['tropospheric chemistry',
#    ' ozone',
#    ' Russia',
#    ' trans-Siberian railroad',
#    ' Siberia',
#    ' carbon monoxide',
#    ' methane',
#    ' nitrogen oxides',
#    ' trace gases',
#    ' atmospheric composition'],
#   'wosid': 'WOS:000072872700005'},
#  {'atitle': 'Carbon monoxide uptake by temperate forest soils: the effects of leaves and humus layers',
#   'date': '1998',
#   'doi': '10.1034/j.1600-0889.1998.00004.x',
#   'jtitle': 'TELLUS SERIES B-CHEMICAL AND PHYSICAL METEOROLOGY',
#   'keywords': None,
#   'wosid': 'WOS:000072142500004'},
#  {'atitle': 'Ozonolysis of nonmethane hydrocarbons as a source of the observed mass independent oxygen isotope enrichment in tropospheric CO',
#   'date': '1998',
#   'doi': '10.1029/97JD02929',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:000071537300008'},
#  {'atitle': 'HALOE observations of the vertical structure of chemical ozone depletion in the Arctic vortex during winter and early spring 1996-1997',
#   'date': '1997',
#   'doi': '10.1029/97GL52834',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1997YG50900008'},
#  {'atitle': 'Modeling the chemistry ozone, halogen compounds, and hydrocarbons in the arctic troposphere during spring',
#   'date': '1997',
#   'doi': '10.1034/j.1600-0889.49.issue5.8.x',
#   'jtitle': 'TELLUS SERIES B-CHEMICAL AND PHYSICAL METEOROLOGY',
#   'keywords': None,
#   'wosid': 'WOS:A1997YJ57700008'},
#  {'atitle': 'Observations of high concentrations of total reactive nitrogen (NOy) and nitric acid (HNO3) in the lower Arctic stratosphere during the stratosphere-troposphere experiment by aircraft measurements (STREAM) II campaign in February 1995',
#   'date': '1997',
#   'doi': '10.1029/97JD02012',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1997YC17100025'},
#  {'atitle': 'Severe chemical ozone loss in the Arctic during the winter of 1995-96',
#   'date': '1997',
#   'doi': '10.1038/39564',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:A1997YA95900049'},
#  {'atitle': 'Tropospheric water-vapour and ozone cross-sections in a zonal plane over the Central Equatorial Pacific Ocean',
#   'date': '1997',
#   'doi': None,
#   'jtitle': 'QUARTERLY JOURNAL OF THE ROYAL METEOROLOGICAL SOCIETY',
#   'keywords': ['balloon-borne sensors',
#    ' humidity',
#    ' tracer transport',
#    ' tropical convection'],
#   'wosid': 'WOS:A1997YC80000011'},
#  {'atitle': 'Modeling gas-phase and aerosol chemistry in the marine boundary layer: Halogens, ozone, and the aerosol pH.',
#   'date': '1997',
#   'doi': None,
#   'jtitle': 'ABSTRACTS OF PAPERS OF THE AMERICAN CHEMICAL SOCIETY',
#   'keywords': None,
#   'wosid': 'WOS:A1997XQ85701038'},
#  {'atitle': 'Temperature dependence of UV absorption cross sections and atmospheric implications of several alkyl iodides',
#   'date': '1997',
#   'doi': '10.1029/97JD00530',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1997XG17900004'},
#  {'atitle': 'Re-formation of chlorine reservoirs in southern hemisphere polar spring',
#   'date': '1997',
#   'doi': '10.1029/96JD03505',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1997XG17900030'},
#  {'atitle': 'Photochemical calculations along air mass trajectories during ASHOE/MAESA',
#   'date': '1997',
#   'doi': '10.1029/96JD03506',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1997XG17900031'},
#  {'atitle': 'Atmospheric aerosols: Biogeochemical sources and role in atmospheric chemistry',
#   'date': '1997',
#   'doi': '10.1126/science.276.5315.1052',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:A1997WZ22500026'},
#  {'atitle': 'Chemical perturbation of the lowermost stratosphere through exchange with the troposphere',
#   'date': '1997',
#   'doi': '10.1029/97GL00255',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1997WL74200028'},
#  {'atitle': 'An inverse modeling approach to investigate the global atmospheric methane cycle',
#   'date': '1997',
#   'doi': '10.1029/96GB03043',
#   'jtitle': 'GLOBAL BIOGEOCHEMICAL CYCLES',
#   'keywords': None,
#   'wosid': 'WOS:A1997WL54100004'},
#  {'atitle': 'Freezing of HNO3/H2SO4/H2O solutions at stratospheric temperatures: Nucleation statistics and experiments',
#   'date': '1997',
#   'doi': '10.1021/jp9626531',
#   'jtitle': 'JOURNAL OF PHYSICAL CHEMISTRY A',
#   'keywords': None,
#   'wosid': 'WOS:A1997WL09000019'},
#  {'atitle': 'Black carbon formation by savanna fires: Measurements and implications for the global carbon cycle',
#   'date': '1996',
#   'doi': '10.1029/95JD02199',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1996VQ49300013'},
#  {'atitle': 'Role of mineral aerosol as a reactive surface in the global troposphere',
#   'date': '1996',
#   'doi': '10.1029/96JD01818',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1996VN18400012'},
#  {'atitle': 'Solute effects on the evaporation of ice particles - Reply',
#   'date': '1996',
#   'doi': '10.1029/96JD01837',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1996VN18400025'},
# ...
#  {'atitle': 'SCIENTIFIC APPLICATION OF BASE-LINE OBSERVATIONS OF ATMOSPHERIC COMPOSITION (SABOAC) .2. EDITORS NOTE',
#   'date': '1986',
#   'doi': None,
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': None,
#   'wosid': 'WOS:A1986A948600001'},
#  {'atitle': 'THE GLOBAL ENVIRONMENT AFTER NUCLEAR-WAR',
#   'date': '1985',
#   'doi': None,
#   'jtitle': 'ENVIRONMENT',
#   'keywords': None,
#   'wosid': 'WOS:A1985ASZ0900004'},
#  {'atitle': 'SCIENTIFIC APPLICATION OF BASELINE OBSERVATIONS OF ATMOSPHERIC COMPOSITION (SABOAC) .1. EDITORS NOTE',
#   'date': '1985',
#   'doi': '10.1007/BF00049365',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': None,
#   'wosid': 'WOS:A1985ASK8800001'},
#  {'atitle': 'TROPOSPHERIC CHEMICAL-COMPOSITION MEASUREMENTS IN BRAZIL DURING THE DRY SEASON',
#   'date': '1985',
#   'doi': '10.1007/BF00051075',
#   'jtitle': 'JOURNAL OF ATMOSPHERIC CHEMISTRY',
#   'keywords': None,
#   'wosid': 'WOS:A1985ADQ4400002'},
#  {'atitle': 'PHOTOCHEMICALLY PRODUCED OZONE IN THE EMISSION FROM LARGE-SCALE TROPICAL VEGETATION FIRES',
#   'date': '1985',
#   'doi': '10.1029/JD090iD01p02425',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1985ACV3600032'},
#  {'atitle': 'DARKNESS AFTER A NUCLEAR-WAR',
#   'date': '1984',
#   'doi': None,
#   'jtitle': 'AMBIO',
#   'keywords': None,
#   'wosid': 'WOS:A1984SE27300017'},
#  {'atitle': 'ATMOSPHERIC EFFECTS FROM POST-NUCLEAR FIRES',
#   'date': '1984',
#   'doi': None,
#   'jtitle': 'CLIMATIC CHANGE',
#   'keywords': None,
#   'wosid': 'WOS:A1984TT80600002'},
#  {'atitle': 'SULFUR-DIOXIDE IN REMOTE OCEANIC AIR - CLOUD TRANSPORT OF REACTIVE PRECURSORS',
#   'date': '1984',
#   'doi': '10.1029/JD089iD05p07111',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1984TH56000001'},
#  {'atitle': 'ATMOSPHERIC EFFECTS OF A NUCLEAR-WAR',
#   'date': '1983',
#   'doi': None,
#   'jtitle': 'CHEMISTRY IN BRITAIN',
#   'keywords': None,
#   'wosid': 'WOS:A1983RR97800020'},
#  {'atitle': 'THE DELTA-BAND DISSOCIATION OF NITRIC-OXIDE - A POTENTIAL MECHANISM FOR COUPLING THERMOSPHERIC VARIATIONS TO THE MESOSPHERE AND STRATOSPHERE',
#   'date': '1983',
#   'doi': '10.1029/JC088iC06p03829',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1983QS52000025'},
#  {'atitle': 'A TWO-DIMENSIONAL PHOTOCHEMICAL MODEL OF THE ATMOSPHERE .1. CHLOROCARBON EMISSIONS AND THEIR EFFECT ON STRATOSPHERIC OZONE',
#   'date': '1983',
#   'doi': '10.1029/JC088iC11p06622',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1983RC61700008'},
#  {'atitle': 'A TWO-DIMENSIONAL PHOTOCHEMICAL MODEL OF THE ATMOSPHERE .2. THE TROPOSPHERIC BUDGETS OF THE ANTHROPOGENIC CHLOROCARBONS CO, CH4, CH3CL AND THE EFFECT OF VARIOUS NOX SOURCES ON TROPOSPHERIC OZONE',
#   'date': '1983',
#   'doi': '10.1029/JC088iC11p06641',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1983RC61700009'},
#  {'atitle': 'CHEMICAL BUDGETS OF THE STRATOSPHERE',
#   'date': '1983',
#   'doi': '10.1016/0032-0633(83)90092-2',
#   'jtitle': 'PLANETARY AND SPACE SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:A1983RJ37400006'},
#  {'atitle': 'THE ATMOSPHERE AFTER A NUCLEAR-WAR - TWILIGHT AT NOON',
#   'date': '1982',
#   'doi': None,
#   'jtitle': 'AMBIO',
#   'keywords': None,
#   'wosid': 'WOS:A1982NS01400006'},
#  {'atitle': 'PHOTOCHEMICAL COUPLING BETWEEN THE THERMOSPHERE AND THE LOWER ATMOSPHERE .1. ODD NITROGEN FROM 50 TO 120 KM',
#   'date': '1982',
#   'doi': '10.1029/JC087iC09p07206',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1982PK32600008'},
#  {'atitle': 'PHOTOCHEMICAL COUPLING BETWEEN THE THERMOSPHERE AND THE LOWER ATMOSPHERE .2. D-REGION ION CHEMISTRY AND THE WINTER ANOMALY',
#   'date': '1982',
#   'doi': '10.1029/JC087iC09p07221',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1982PK32600009'},
#  {'atitle': 'EVALUATED KINETIC AND PHOTOCHEMICAL DATA FOR ATMOSPHERIC CHEMISTRY .1. CODATA TASK GROUP ON CHEMICAL-KINETICS',
#   'date': '1982',
#   'doi': None,
#   'jtitle': 'JOURNAL OF PHYSICAL AND CHEMICAL REFERENCE DATA',
#   'keywords': None,
#   'wosid': 'WOS:A1982PM79400003'},
#  {'atitle': 'THE ROLE OF FIXED NITROGEN IN ATMOSPHERIC PHOTOCHEMISTRY',
#   'date': '1982',
#   'doi': '10.1098/rstb.1982.0024',
#   'jtitle': 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON SERIES B-BIOLOGICAL SCIENCES',
#   'keywords': None,
#   'wosid': 'WOS:A1982MZ86600019'},
#  {'atitle': 'TERMITES - A POTENTIALLY LARGE SOURCE OF ATMOSPHERIC METHANE, CARBON-DIOXIDE, AND MOLECULAR-HYDROGEN',
#   'date': '1982',
#   'doi': '10.1126/science.218.4572.563',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:A1982PM84400025'},
#  {'atitle': 'ANALYSIS OF THE AUGUST 1972 SOLAR PROTON EVENT INCLUDING CHLORINE CHEMISTRY',
#   'date': '1981',
#   'doi': '10.1029/JC086iC02p01140',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1981LP22500004'},
#  {'atitle': 'The effect of particle precipitation events on the neutral and ion chemistry of the middle atmosphere -I. Odd nitrogen',
#   'date': '1981',
#   'doi': '10.1016/0032-0633(81)90048-9',
#   'jtitle': 'PLANETARY AND SPACE SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:A1981LY64000011'},
#  {'atitle': 'THE EFFECT OF PARTICLE-PRECIPITATION EVENTS ON THE NEUTRAL AND ION CHEMISTRY OF THE MIDDLE ATMOSPHERE .2. ODD HYDROGEN',
#   'date': '1981',
#   'doi': '10.1016/0032-0633(81)90078-7',
#   'jtitle': 'PLANETARY AND SPACE SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:A1981MK07500009'},
#  {'atitle': 'ESTIMATES OF GROSS AND NET FLUXES OF CARBON BETWEEN THE BIOSPHERE AND THE ATMOSPHERE FROM BIOMASS BURNING',
#   'date': '1980',
#   'doi': '10.1007/BF00137988',
#   'jtitle': 'CLIMATIC CHANGE',
#   'keywords': None,
#   'wosid': 'WOS:A1980JQ59200002'},
#  {'atitle': '1ST MEASUREMENTS OF TOTAL CHLORINE AND BROMINE IN THE LOWER STRATOSPHERE',
#   'date': '1980',
#   'doi': '10.1029/GL007i011p00937',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1980KS93900021'},
#  {'atitle': 'LATITUDINAL DISTRIBUTIONS OF CO AND CH4 OVER THE PACIFIC',
#   'date': '1980',
#   'doi': '10.1029/JC085iC12p07329',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1980KW80200005'},
#  {'atitle': 'RESPONSE OF MESOPHERIC OZONE TO PARTICLE-PRECIPITATION',
#   'date': '1980',
#   'doi': '10.1016/0032-0633(80)90073-2',
#   'jtitle': 'PLANETARY AND SPACE SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:A1980KV29000007'},
#  {'atitle': 'SCIENTIFIC OBJECTIVES OF THE SOLAR MESOSPHERE EXPLORER MISSION',
#   'date': '1980',
#   'doi': '10.1007/BF01586468',
#   'jtitle': 'PURE AND APPLIED GEOPHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:A1980JR92200026'},
#  {'atitle': 'ROLE OF NO AND NO2 IN THE CHEMISTRY OF THE TROPOSPHERE AND STRATOSPHERE',
#   'date': '1979',
#   'doi': '10.1146/annurev.ea.07.050179.002303',
#   'jtitle': 'ANNUAL REVIEW OF EARTH AND PLANETARY SCIENCES',
#   'keywords': None,
#   'wosid': 'WOS:A1979GV57000017'},
#  {'atitle': 'ACTINOMETRIC MEASUREMENTS AND THEORETICAL CALCULATIONS OF J(O3), THE RATE OF PHOTOLYSIS OF OZONE TO O(1D)',
#   'date': '1979',
#   'doi': '10.1029/GL006i011p00833',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1979HW77600005'},
#  {'atitle': 'BIOMASS BURNING AS A SOURCE OF ATMOSPHERIC GASES CO, H-2, N2O, NO, CH3CL AND COS',
#   'date': '1979',
#   'doi': '10.1038/282253a0',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:A1979HU09200028'},
#  {'atitle': 'TROPOSPHERIC OZONE AND CLIMATE',
#   'date': '1979',
#   'doi': '10.1038/282818a0',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:A1979HY94600043'},
#  {'atitle': 'CHLOROFLUOROMETHANES - THREATS TO THE OZONE-LAYER',
#   'date': '1979',
#   'doi': '10.1029/RG017i007p01824',
#   'jtitle': 'REVIEWS OF GEOPHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:A1979HS40600030'},
#  {'atitle': 'OBSERVATIONAL AND THEORETICAL EVIDENCE IN SUPPORT OF A SIGNIFICANT INSITU PHOTO-CHEMICAL SOURCE OF TROPOSPHERIC OZONE',
#   'date': '1979',
#   'doi': None,
#   'jtitle': 'TELLUS',
#   'keywords': None,
#   'wosid': 'WOS:A1979HV49600007'},
#  {'atitle': 'INTERACTION OF ODD HYDROGEN AND ODD CHLORINE PHOTOCHEMISTRY AND THEIR ROLES IN CATALYTIC DESTRUCTION OF STRATOSPHERIC OZONE',
#   'date': '1978',
#   'doi': None,
#   'jtitle': 'ABSTRACTS OF PAPERS OF THE AMERICAN CHEMICAL SOCIETY',
#   'keywords': None,
#   'wosid': 'WOS:A1978FL88300938'},
#  {'atitle': 'ESTIMATES ON PRODUCTION OF CO AND H-2 FROM OXIDATION OF HYDROCARBON EMISSIONS FROM VEGETATION',
#   'date': '1978',
#   'doi': '10.1029/GL005i008p00679',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1978FM60300015'},
#  {'atitle': 'IMPACT OF CHLORO-CARBON INDUSTRY ON OZONE-LAYER',
#   'date': '1978',
#   'doi': '10.1029/JC083iC01p00345',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1978EK56000001'},
#  {'atitle': 'TROPOSPHERIC N2O MIXING RATIO MEASUREMENTS',
#   'date': '1978',
#   'doi': '10.1029/JC083iC02p00935',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1978EN22500006'},
#  {'atitle': 'EFFECTS OF INTENSE STRATOSPHERIC IONIZATION EVENTS',
#   'date': '1978',
#   'doi': '10.1038/275489a0',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:A1978FS34900023'},
#  {'atitle': 'ORIGIN OF OZONE IN TROPOSPHERE',
#   'date': '1978',
#   'doi': '10.1038/274855a0',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:A1978FM47900016'},
#  {'atitle': 'EFFECT OF HO2+NO REACTION-RATE CONSTANT ON ONE-DIMENSIONAL MODEL CALCULATIONS OF STRATOSPHERIC OZONE PERTURBATIONS',
#   'date': '1978',
#   'doi': '10.1007/BF01636903',
#   'jtitle': 'PURE AND APPLIED GEOPHYSICS',
#   'keywords': None,
#   'wosid': 'WOS:A1978EW06400026'},
#  {'atitle': 'AVERAGE CONCENTRATIONS OF OH IN TROPOSPHERE, AND BUDGETS OF CH4 CO H-2 + CH3CCL3',
#   'date': '1977',
#   'doi': '10.1029/GL004i008p00321',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1977DS85300006'},
#  {'atitle': 'TROPOSPHERIC AND STRATOSPHERIC COMPOSITION PERTURBED BY NOX EMISSIONS OF HIGH-ALTITUDE AIRCRAFT',
#   'date': '1977',
#   'doi': '10.1029/JC082i037p05833',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1977EF27400003'},
#  {'atitle': 'NUMERICAL STUDY OF TROPOSPHERIC PHOTOCHEMISTRY USING A ONE-DIMENSIONAL MODEL',
#   'date': '1977',
#   'doi': '10.1029/JC082i037p05897',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1977EF27400007'},
#  {'atitle': 'STRATOSPHERIC NITROUS-OXIDE ALTITUDE PROFILES AT VARIOUS LATITUDES',
#   'date': '1977',
#   'doi': '10.1175/1520-0469(1977)034<0729:SNOAPA>2.0.CO;2',
#   'jtitle': 'JOURNAL OF THE ATMOSPHERIC SCIENCES',
#   'keywords': None,
#   'wosid': 'WOS:A1977DG11600005'},
#  {'atitle': 'SOLAR PROTON EVENT - INFLUENCE ON STRATOSPHERIC OZONE',
#   'date': '1977',
#   'doi': '10.1126/science.197.4306.886',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:A1977DR70100015'},
#  {'atitle': 'STRATOSPHERIC EDDY DIFFUSION-COEFFICIENTS FROM NITROUS-OXIDE MEASUREMENTS',
#   'date': '1977',
#   'doi': None,
#   'jtitle': 'TRANSACTIONS-AMERICAN GEOPHYSICAL UNION',
#   'keywords': None,
#   'wosid': 'WOS:A1977DP36300063'},
#  {'atitle': 'ATTEMPT TO RECONSTRUCT COMPOSITION OF PRE-INDUSTRIAL ATMOSPHERE',
#   'date': '1977',
#   'doi': None,
#   'jtitle': 'TRANSACTIONS-AMERICAN GEOPHYSICAL UNION',
#   'keywords': None,
#   'wosid': 'WOS:A1977DP36300072'},
#  {'atitle': 'COMPUTED AND OBSERVED DIFFERENCES BETWEEN NORTHERN AND SOUTHERN-HEMISPHERE DISTRIBUTION OF VARIOUS TRACE CONSTITUENTS IN TROPOSPHERE',
#   'date': '1977',
#   'doi': None,
#   'jtitle': 'TRANSACTIONS-AMERICAN GEOPHYSICAL UNION',
#   'keywords': None,
#   'wosid': 'WOS:A1977EA42500228'},
#  {'atitle': 'POSSIBLE IMPORTANCE OF CSO FOR SULFATE LAYER OF STRATOSPHERE',
#   'date': '1976',
#   'doi': '10.1029/GL003i002p00073',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1976BG97100007'},
#  {'atitle': 'UPPER LIMITS ON ATMOSPHERIC OZONE REDUCTIONS FOLLOWING INCREASED APPLICATION OF FIXED NITROGEN TO SOIL',
#   'date': '1976',
#   'doi': '10.1029/GL003i003p00169',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1976BL04700015'},
#  {'atitle': 'ION CHEMISTRY OF CHLORINE COMPOUNDS IN TROPOSPHERE AND STRATOSPHERE',
#   'date': '1976',
#   'doi': '10.1029/JC081i024p04454',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1976CC17400005'},
#  {'atitle': 'INFLUENCE OF ANCIENT SOLAR-PROTON EVENTS ON EVOLUTION OF LIFE',
#   'date': '1976',
#   'doi': '10.1038/259177a0',
#   'jtitle': 'NATURE',
#   'keywords': None,
#   'wosid': 'WOS:A1976BC68300013'},
#  {'atitle': 'MEASUREMENTS OF STRATOSPHERIC CFCL3, CF2CL2, AND N2O',
#   'date': '1975',
#   'doi': '10.1029/GL002i009p00393',
#   'jtitle': 'GEOPHYSICAL RESEARCH LETTERS',
#   'keywords': None,
#   'wosid': 'WOS:A1975AS03600008'},
#  {'atitle': 'STRATOSPHERIC THICKNESS VARIATIONS OVER NORTHERN HEMISPHERE AND THEIR POSSIBLE RELATION TO SOLAR-ACTIVITY',
#   'date': '1975',
#   'doi': '10.1029/JC080i036p05041',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH-OCEANS AND ATMOSPHERES',
#   'keywords': None,
#   'wosid': 'WOS:A1975BA25800011'},
#  {'atitle': 'SOLAR PROTON EVENTS - STRATOSPHERIC SOURCES OF NITRIC-OXIDE',
#   'date': '1975',
#   'doi': '10.1126/science.189.4201.457',
#   'jtitle': 'SCIENCE',
#   'keywords': None,
#   'wosid': 'WOS:A1975AK43600022'},
#  {'atitle': 'PHOTOCHEMICAL REACTIONS INITIATED BY AND INFLUENCING OZONE IN UNPOLLUTED TROPOSPHERIC AIR',
#   'date': '1974',
#   'doi': None,
#   'jtitle': 'TELLUS',
#   'keywords': None,
#   'wosid': 'WOS:A1974T559500007'},
#  {'atitle': 'FUTURE EFFECTS OF CONTINUED USE OF CHLORO-FLUORO-METHANES ON STRATOSPHERIC OZONE',
#   'date': '1974',
#   'doi': None,
#   'jtitle': 'TRANSACTIONS-AMERICAN GEOPHYSICAL UNION',
#   'keywords': None,
#   'wosid': 'WOS:A1974U698100417'},
#  {'atitle': 'CHEMISTRY OF IMPORTANT MINOR CONSTITUENTS IN ATMOSPHERE',
#   'date': '1973',
#   'doi': None,
#   'jtitle': 'TRANSACTIONS-AMERICAN GEOPHYSICAL UNION',
#   'keywords': None,
#   'wosid': 'WOS:A1973P434100016'},
#  {'atitle': 'COMMENTS ON REPORT NO 15 OF AUSTRALIAN ACADEMY OF SCIENCE - ATMOSPHERIC EFFECTS OF SUPERSONIC AIRCRAFT',
#   'date': '1972',
#   'doi': None,
#   'jtitle': 'SEARCH',
#   'keywords': None,
#   'wosid': 'WOS:A1972N111800004'},
#  {'atitle': 'CALCULATION OF [O2(1DELTAG)] IN ATMOSPHERE USING NEW LABORATORY DATA',
#   'date': '1971',
#   'doi': '10.1029/JC076i006p01490',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH',
#   'keywords': None,
#   'wosid': 'WOS:A1971I688400003'},
#  {'atitle': 'OZONE PRODUCTION RATES IN AN OXYGEN-HYDROGEN-NITROGEN OXIDE ATMOSPHERE',
#   'date': '1971',
#   'doi': '10.1029/JC076i030p07311',
#   'jtitle': 'JOURNAL OF GEOPHYSICAL RESEARCH',
#   'keywords': None,
#   'wosid': 'WOS:A1971K614800001'},
#  {'atitle': 'INFLUENCE OF NITROGEN OXIDES ON ATMOSPHERIC OZONE CONTENT',
#   'date': '1970',
#   'doi': '10.1002/qj.49709640815',
#   'jtitle': 'QUARTERLY JOURNAL OF THE ROYAL METEOROLOGICAL SOCIETY',
#   'keywords': None,
#   'wosid': 'WOS:A1970G322300014'},
#  {'atitle': 'ABSORPTION AND EMISSION BY CARBON-DIOXIDE IN MESOSPHERE',
#   'date': '1970',
#   'doi': None,
#   'jtitle': 'QUARTERLY JOURNAL OF THE ROYAL METEOROLOGICAL SOCIETY',
#   'keywords': None,
#   'wosid': 'WOS:A1970H742100026'},
#  {'atitle': 'DETERMINATION OF PARAMETERS APPEARING IN DRY AND WET PHOTOCHEMICAL THEORIES FOR OZONE IN STRATOSPHERE',
#   'date': '1969',
#   'doi': None,
#   'jtitle': 'TELLUS',
#   'keywords': None,
#   'wosid': 'WOS:A1969D552900007'},
#  {'atitle': 'A PHOTOCHEMICAL MODEL FOR SPACE-TIME VARIATIONS OF OXYGEN ALLOTROPES IN 20 TO 100 KM LAYER',
#   'date': '1966',
#   'doi': None,
#   'jtitle': 'TELLUS',
#   'keywords': None,
#   'wosid': 'WOS:A19668560400003'}]

# %%
# December 1

# Initialize to avoid overwriting
keywords_list = []
side_list=[]
main_dict ={}
count=1


# This loop runs for each paper
for r in dir_papers:
    if r['keywords']:
        print "count::" , count
        #print "################################Keywords::" , r['keywords'] , r['date']
        
        
        ### Make the lists empty to avoid overwriting
        keywords_list = []
        side_list=[]
        
        
        ### This loop runs for each each keyword of a paper
        for each_kw in r['keywords']:
            each_kw = each_kw.strip().lower() # convert to lowercase, even if it is not.
            try:
                main_dict[r['date']][0].keys() # to direct it to main_dict
                if r['date'] in main_dict.keys():
                    lst = [item.keys() for item in main_dict[r['date']]]
                    for i in lst:
                            for j in i:
                                if j not in side_list:
                                    side_list.append(j)
                    if any(each_kw in st for st in lst):
                        #print "##ALREADY"
                        kw_index = side_list.index(each_kw)
                        main_dict[r['date']][kw_index][each_kw] += 1
                        #print "cool*************" ,main_dict[r['date']] 
                    
                    else:
                       #print "##else"
                        new_dict={}
                        new_dict[each_kw] = 1
                        main_dict[r['date']].append(new_dict)
                        #print "main dict here$$$$$$$ " , main_dict
                        #print "herererrerer" , main_dict[r['date']]      
                           
            except:
                #print "except",main_dict
                keywords_dict={}
                side_list=[]
                keywords_dict[each_kw] = 1
                keywords_list.append(keywords_dict)
                main_dict[r['date']]= keywords_list  
                #print "keywords_dict" , keywords_dict , "keywords_list", keywords_list
                #print "maindict in except" , main_dict
        count=count+1
# Out:
# count:: 1
# count:: 2
# count:: 3
# count:: 4
# count:: 5
# count:: 6
# count:: 7
# count:: 8
# count:: 9
# count:: 10
# count:: 11
# count:: 12
# count:: 13
# count:: 14
# count:: 15
# count:: 16
# count:: 17
# count:: 18
# count:: 19
# count:: 20
# count:: 21
# count:: 22
# count:: 23
# count:: 24
# count:: 25
# count:: 26
# count:: 27
# count:: 28
# count:: 29
# count:: 30
# count:: 31
# count:: 32
# count:: 33
# count:: 34
# count:: 35
# count:: 36
# count:: 37
# count:: 38
# count:: 39
# count:: 40
# count:: 41
# count:: 42
# count:: 43
# count:: 44
# count:: 45
# count:: 46
# count:: 47
# count:: 48

# %%
main_dict
# Out:
# {'1991': [{'troposphere': 1},
#   {'photochemistry': 1},
#   {'clouds': 1},
#   {'ozone': 1}],
#  '1992': [{'crystal growth': 1}, {'nucleation': 1}, {'supercooling': 1}],
#  '1994': [{'global model': 1},
#   {'emission inventory': 1},
#   {'ammonia': 1},
#   {'ammonium': 1},
#   {'nitrous oxide': 1},
#   {'acidity': 1},
#   {'canopy compensation point': 1}],
#  '1995': [{'animal waste': 1},
#   {'volatilization of aliphatic amines': 1},
#   {'atmospheric chemistry of methylamines': 1},
#   {'global n2o': 1},
#   {'hcn budgets': 1},
#   {'model': 1},
#   {'orographic cloud': 1},
#   {'sulfur': 1},
#   {'nitrogen oxides': 1},
#   {'heterogeneous oxidation': 1},
#   {'iron catalysis': 1},
#   {'henrys law': 1},
#   {'droplet size spectrum': 1}],
#  '1996': [{'atmospheric chemistry': 1},
#   {'nobel lecture': 1},
#   {'ozone': 1},
#   {'animal manure': 1},
#   {'nitrous oxide release': 1},
#   {'methane release': 1},
#   {'agricultural nitrogen budget': 1},
#   {'tropospheric methane': 1},
#   {'ch4 emissions': 1},
#   {'natural gas': 1},
#   {'tracers': 1}],
#  '1997': [{'balloon-borne sensors': 1},
#   {'humidity': 1},
#   {'tracer transport': 1},
#   {'tropical convection': 1}],
#  '1998': [{'atmospheric composition and structure': 1},
#   {'middle atmosphere': 1},
#   {'meteorology and atmospheric dynamics': 1},
#   {'climatology': 1},
#   {'general circulation': 1},
#   {'tropospheric chemistry': 1},
#   {'ozone': 1},
#   {'russia': 1},
#   {'trans-siberian railroad': 1},
#   {'siberia': 1},
#   {'carbon monoxide': 1},
#   {'methane': 1},
#   {'nitrogen oxides': 1},
#   {'trace gases': 1},
#   {'atmospheric composition': 1}],
#  '1999': [{'ozone': 2},
#   {'co': 1},
#   {'biomass burning': 1},
#   {'tropical savannah': 1},
#   {'ozone production ratio': 1},
#   {'upper stratosphere': 1},
#   {'ozone budget': 1},
#   {'ozone deficit problem': 1},
#   {'haloe': 1},
#   {'convection': 1},
#   {'equatorial pacific': 1},
#   {'global modelling': 1},
#   {'tropics': 1},
#   {'aerosol': 1},
#   {'iodine chemistry': 1},
#   {'halogen chemistry': 1},
#   {'marine boundary layer': 1},
#   {'modeling': 1},
#   {'ozone loss': 1},
#   {'sea salt': 1},
#   {'chemical ozone loss (arctic vortex 1995-96': 1},
#   {'halogen chemistry)': 1}],
#  '2000': [{'isoprene oxidation': 1},
#   {'global atmospheric modeling': 1},
#   {'condensed chemical mechanism': 1},
#   {'precipitation scavenging': 1},
#   {"henry's lawdependence": 1},
#   {'global model study': 1},
#   {'convection': 1},
#   {'gasrejection on freezing': 1},
#   {'trace gas vertical transport': 1},
#   {'non-methane hydrocarbons': 1},
#   {'ozone': 1},
#   {'hox': 1},
#   {'co': 1},
#   {'nox': 1},
#   {'tropospheric chemistry': 1},
#   {'global': 1},
#   {'3-d modeling': 1},
#   {'upper troposphere': 1},
#   {'proton transfer mass spectrometer (ptr-ms)': 1},
#   {'tropical rainforest emissions': 1},
#   {'volatile organic compounds (voc)': 1},
#   {'isoprene': 1},
#   {'isoprene oxidation products': 1},
#   {'methacrolein': 1},
#   {'methyl vinyl ketone': 1},
#   {'upper tropospheric ho(x)': 1},
#   {'acetone': 2},
#   {'aircraft no emissions': 1},
#   {'nmhc': 1},
#   {'photochemical model': 1},
#   {'hydroxyl': 1},
#   {'upper tropospheric ozone': 1},
#   {'pan': 1}],
#  '2001': [{'lba-claire': 1},
#   {'atmospheric tropical photochemistry': 1},
#   {'tropical forest': 1},
#   {'ozone': 1},
#   {'hydrogenperoxide': 1},
#   {'gaseous organic acids': 1},
#   {'flux-form advection': 1},
#   {'mass-wind inconsistency': 1},
#   {'3-d model': 1},
#   {'tracer transport': 1},
#   {'acetone': 2},
#   {'tropical rainforest emissions': 2},
#   {'proton-transfer reaction mass spectrometry': 1},
#   {'carbon monoxide': 1},
#   {'acetonitrile': 2},
#   {'2-propanol': 1},
#   {'biomass burning': 1},
#   {'surinam': 1},
#   {'proton transfer mass spectrometer (ptr-ms)': 1},
#   {'volatile organic compounds (voc)': 1},
#   {'isoprene': 2},
#   {'isoprene oxidation products': 2},
#   {'methacrolein': 2},
#   {'methyl vinyl ketone': 1},
#   {'upper tropospheric ho(x)': 1},
#   {'tropical oh': 1},
#   {'tropical forest boundary layer': 1},
#   {'box model': 1},
#   {'methylvinylketone': 1},
#   {'anthropogenic activities': 1},
#   {'effects on the atmosphere': 1},
#   {'stratospheric ozone depletion': 1},
#   {'photochemical ozone production': 1},
#   {'ozone hole': 1},
#   {'ch4': 1},
#   {'nox': 1},
#   {'co': 1},
#   {'hox': 1},
#   {'clox': 1}],
#  '2002': [{'tropospheric ozone budget': 1},
#   {'electricity induced trace gas production': 1},
#   {'stratosphere-to-troposphere ozone': 1},
#   {'ptr-ms': 2},
#   {'savanna': 1},
#   {'isoprene oxidation': 1},
#   {'biogenic emissions': 1},
#   {'bromine': 3},
#   {'aerosol': 1},
#   {'marine boundary layer': 2},
#   {'indoex': 3},
#   {'leaded fuel': 1},
#   {'indian ocean': 1},
#   {'nmhc': 1},
#   {'isotopes': 1},
#   {'air mass classification': 1},
#   {'long-range transport': 1},
#   {'sea-salt aerosol': 2},
#   {'cloud chemistry': 1},
#   {'halogen chemistry': 1},
#   {'chlorine': 2},
#   {'sulfur-halogen interactions': 1},
#   {'o-3 destruction': 1},
#   {'aerosol chemistry': 1},
#   {'iodine': 1},
#   {'vocs': 1},
#   {'biomass burning': 1},
#   {'acetone': 1},
#   {'acetonitrile': 1},
#   {'intertropical convergence zone': 1},
#   {'carbon monoxide': 1},
#   {'ozone': 1},
#   {'relative humidity': 1},
#   {'stratosphere-troposphere exchange': 1},
#   {'tropical cyclone': 1},
#   {'convection': 1},
#   {'interhemispheric exchange': 1},
#   {'tropospheric chemistry': 1},
#   {'boundary layer': 1},
#   {'wetlands': 1},
#   {'russia': 1},
#   {'siberia': 1},
#   {'trans-siberian railroad': 1},
#   {'formaldehyde': 1},
#   {'ch2o': 1},
#   {'hcho': 1},
#   {'troposphere': 1},
#   {'budget': 1}],
#  '2003': [{'model evaluation': 1},
#   {'nonmethane hydrocarbons': 2},
#   {'ozone precursors': 1},
#   {'biomass burning': 2},
#   {'oxygenated organic compounds': 1},
#   {'indonesian fires': 1},
#   {'aerosol chemical characterization': 1},
#   {'fossil fuel combustion': 1},
#   {'chemistry-climate model': 1},
#   {'stratospheric ozone': 1},
#   {'uars satellite data': 1},
#   {'chlorine partitioning': 1},
#   {'polar ozone': 1},
#   {'global model': 1},
#   {'ozone budget': 1},
#   {'tropospheric ozone': 1},
#   {'stratosphere-troposphere exchange': 1},
#   {'mass-wind inconsistency': 1}],
#  '2004': [{'ozone-depleting substances': 1},
#   {'emissions': 1},
#   {'russia': 1},
#   {'instrument intercomparision': 1},
#   {'biomass burning': 1},
#   {'oxygenated organic compounds': 1}],
#  '2006': [{'iridium': 1},
#   {'platinum': 1},
#   {'meteoric smoke': 1},
#   {'ice': 1},
#   {'antarctica': 1},
#   {'climate': 1}],
#  '2010': [{'oceanic impact': 1},
#   {'near-earth-object': 1},
#   {'modeling': 1},
#   {'ozone perturbation': 1},
#   {'atmospheric chemistry': 1}],
#  '2012': [{'assessments': 1},
#   {'ecology': 1},
#   {'sustainability': 1},
#   {'interdisciplinary science': 1},
#   {'policy': 1},
#   {'ethics': 1},
#   {'nitrous oxide': 1},
#   {'biofuels': 1},
#   {'reactive n': 1},
#   {'agriculture': 1},
#   {'n2o emission factor': 1},
#   {'life cycle analysis': 1}]}

# %%
    #Prepare the dict for CSV
    from collections import defaultdict as dd
    
    papers = []
    main_list =[]
    

    for k,val in main_dict.iteritems():
            #print k
            paper = KeyPaper()
            for j in val:
                print j
                for l,m in j.iteritems():
                    paper['date'] = k
                    paper['keywords'] = l
                    paper['count'] = m
                    main_list.append(paper)
                    paper={}
                    
  
    #print "main_list", main_list
# Out:
# 1991
# paper {'date': None, 'count': None, 'keywords': None}
# {'troposphere': 1}
# {'photochemistry': 1}
# {'clouds': 1}
# {'ozone': 1}
# 1992
# paper {'date': None, 'count': None, 'keywords': None}
# {'crystal growth': 1}
# {'nucleation': 1}
# {'supercooling': 1}
# 1995
# paper {'date': None, 'count': None, 'keywords': None}
# {'animal waste': 1}
# {'volatilization of aliphatic amines': 1}
# {'atmospheric chemistry of methylamines': 1}
# {'global n2o': 1}
# {'hcn budgets': 1}
# {'model': 1}
# {'orographic cloud': 1}
# {'sulfur': 1}
# {'nitrogen oxides': 1}
# {'heterogeneous oxidation': 1}
# {'iron catalysis': 1}
# {'henrys law': 1}
# {'droplet size spectrum': 1}
# 1994
# paper {'date': None, 'count': None, 'keywords': None}
# {'global model': 1}
# {'emission inventory': 1}
# {'ammonia': 1}
# {'ammonium': 1}
# {'nitrous oxide': 1}
# {'acidity': 1}
# {'canopy compensation point': 1}
# 1997
# paper {'date': None, 'count': None, 'keywords': None}
# {'balloon-borne sensors': 1}
# {'humidity': 1}
# {'tracer transport': 1}
# {'tropical convection': 1}
# 1996
# paper {'date': None, 'count': None, 'keywords': None}
# {'atmospheric chemistry': 1}
# {'nobel lecture': 1}
# {'ozone': 1}
# {'animal manure': 1}
# {'nitrous oxide release': 1}
# {'methane release': 1}
# {'agricultural nitrogen budget': 1}
# {'tropospheric methane': 1}
# {'ch4 emissions': 1}
# {'natural gas': 1}
# {'tracers': 1}
# 1999
# paper {'date': None, 'count': None, 'keywords': None}
# {'ozone': 2}
# {'co': 1}
# {'biomass burning': 1}
# {'tropical savannah': 1}
# {'ozone production ratio': 1}
# {'upper stratosphere': 1}
# {'ozone budget': 1}
# {'ozone deficit problem': 1}
# {'haloe': 1}
# {'convection': 1}
# {'equatorial pacific': 1}
# {'global modelling': 1}
# {'tropics': 1}
# {'aerosol': 1}
# {'iodine chemistry': 1}
# {'halogen chemistry': 1}
# {'marine boundary layer': 1}
# {'modeling': 1}
# {'ozone loss': 1}
# {'sea salt': 1}
# {'chemical ozone loss (arctic vortex 1995-96': 1}
# {'halogen chemistry)': 1}
# 1998
# paper {'date': None, 'count': None, 'keywords': None}
# {'atmospheric composition and structure': 1}
# {'middle atmosphere': 1}
# {'meteorology and atmospheric dynamics': 1}
# {'climatology': 1}
# {'general circulation': 1}
# {'tropospheric chemistry': 1}
# {'ozone': 1}
# {'russia': 1}
# {'trans-siberian railroad': 1}
# {'siberia': 1}
# {'carbon monoxide': 1}
# {'methane': 1}
# {'nitrogen oxides': 1}
# {'trace gases': 1}
# {'atmospheric composition': 1}
# 2002
# paper {'date': None, 'count': None, 'keywords': None}
# {'tropospheric ozone budget': 1}
# {'electricity induced trace gas production': 1}
# {'stratosphere-to-troposphere ozone': 1}
# {'ptr-ms': 2}
# {'savanna': 1}
# {'isoprene oxidation': 1}
# {'biogenic emissions': 1}
# {'bromine': 3}
# {'aerosol': 1}
# {'marine boundary layer': 2}
# {'indoex': 3}
# {'leaded fuel': 1}
# {'indian ocean': 1}
# {'nmhc': 1}
# {'isotopes': 1}
# {'air mass classification': 1}
# {'long-range transport': 1}
# {'sea-salt aerosol': 2}
# {'cloud chemistry': 1}
# {'halogen chemistry': 1}
# {'chlorine': 2}
# {'sulfur-halogen interactions': 1}
# {'o-3 destruction': 1}
# {'aerosol chemistry': 1}
# {'iodine': 1}
# {'vocs': 1}
# {'biomass burning': 1}
# {'acetone': 1}
# {'acetonitrile': 1}
# {'intertropical convergence zone': 1}
# {'carbon monoxide': 1}
# {'ozone': 1}
# {'relative humidity': 1}
# {'stratosphere-troposphere exchange': 1}
# {'tropical cyclone': 1}
# {'convection': 1}
# {'interhemispheric exchange': 1}
# {'tropospheric chemistry': 1}
# {'boundary layer': 1}
# {'wetlands': 1}
# {'russia': 1}
# {'siberia': 1}
# {'trans-siberian railroad': 1}
# {'formaldehyde': 1}
# {'ch2o': 1}
# {'hcho': 1}
# {'troposphere': 1}
# {'budget': 1}
# 2003
# paper {'date': None, 'count': None, 'keywords': None}
# {'model evaluation': 1}
# {'nonmethane hydrocarbons': 2}
# {'ozone precursors': 1}
# {'biomass burning': 2}
# {'oxygenated organic compounds': 1}
# {'indonesian fires': 1}
# {'aerosol chemical characterization': 1}
# {'fossil fuel combustion': 1}
# {'chemistry-climate model': 1}
# {'stratospheric ozone': 1}
# {'uars satellite data': 1}
# {'chlorine partitioning': 1}
# {'polar ozone': 1}
# {'global model': 1}
# {'ozone budget': 1}
# {'tropospheric ozone': 1}
# {'stratosphere-troposphere exchange': 1}
# {'mass-wind inconsistency': 1}
# 2000
# paper {'date': None, 'count': None, 'keywords': None}
# {'isoprene oxidation': 1}
# {'global atmospheric modeling': 1}
# {'condensed chemical mechanism': 1}
# {'precipitation scavenging': 1}
# {"henry's lawdependence": 1}
# {'global model study': 1}
# {'convection': 1}
# {'gasrejection on freezing': 1}
# {'trace gas vertical transport': 1}
# {'non-methane hydrocarbons': 1}
# {'ozone': 1}
# {'hox': 1}
# {'co': 1}
# {'nox': 1}
# {'tropospheric chemistry': 1}
# {'global': 1}
# {'3-d modeling': 1}
# {'upper troposphere': 1}
# {'proton transfer mass spectrometer (ptr-ms)': 1}
# {'tropical rainforest emissions': 1}
# {'volatile organic compounds (voc)': 1}
# {'isoprene': 1}
# {'isoprene oxidation products': 1}
# {'methacrolein': 1}
# {'methyl vinyl ketone': 1}
# {'upper tropospheric ho(x)': 1}
# {'acetone': 2}
# {'aircraft no emissions': 1}
# {'nmhc': 1}
# {'photochemical model': 1}
# {'hydroxyl': 1}
# {'upper tropospheric ozone': 1}
# {'pan': 1}
# 2001
# paper {'date': None, 'count': None, 'keywords': None}
# {'lba-claire': 1}
# {'atmospheric tropical photochemistry': 1}
# {'tropical forest': 1}
# {'ozone': 1}
# {'hydrogenperoxide': 1}
# {'gaseous organic acids': 1}
# {'flux-form advection': 1}
# {'mass-wind inconsistency': 1}
# {'3-d model': 1}
# {'tracer transport': 1}
# {'acetone': 2}
# {'tropical rainforest emissions': 2}
# {'proton-transfer reaction mass spectrometry': 1}
# {'carbon monoxide': 1}
# {'acetonitrile': 2}
# {'2-propanol': 1}
# {'biomass burning': 1}
# {'surinam': 1}
# {'proton transfer mass spectrometer (ptr-ms)': 1}
# {'volatile organic compounds (voc)': 1}
# {'isoprene': 2}
# {'isoprene oxidation products': 2}
# {'methacrolein': 2}
# {'methyl vinyl ketone': 1}
# {'upper tropospheric ho(x)': 1}
# {'tropical oh': 1}
# {'tropical forest boundary layer': 1}
# {'box model': 1}
# {'methylvinylketone': 1}
# {'anthropogenic activities': 1}
# {'effects on the atmosphere': 1}
# {'stratospheric ozone depletion': 1}
# {'photochemical ozone production': 1}
# {'ozone hole': 1}
# {'ch4': 1}
# {'nox': 1}
# {'co': 1}
# {'hox': 1}
# {'clox': 1}
# 2006
# paper {'date': None, 'count': None, 'keywords': None}
# {'iridium': 1}
# {'platinum': 1}
# {'meteoric smoke': 1}
# {'ice': 1}
# {'antarctica': 1}
# {'climate': 1}
# 2004
# paper {'date': None, 'count': None, 'keywords': None}
# {'ozone-depleting substances': 1}
# {'emissions': 1}
# {'russia': 1}
# {'instrument intercomparision': 1}
# {'biomass burning': 1}
# {'oxygenated organic compounds': 1}
# 2010
# paper {'date': None, 'count': None, 'keywords': None}
# {'oceanic impact': 1}
# {'near-earth-object': 1}
# {'modeling': 1}
# {'ozone perturbation': 1}
# {'atmospheric chemistry': 1}
# 2012
# paper {'date': None, 'count': None, 'keywords': None}
# {'assessments': 1}
# {'ecology': 1}
# {'sustainability': 1}
# {'interdisciplinary science': 1}
# {'policy': 1}
# {'ethics': 1}
# {'nitrous oxide': 1}
# {'biofuels': 1}
# {'reactive n': 1}
# {'agriculture': 1}
# {'n2o emission factor': 1}
# {'life cycle analysis': 1}
# main_list [{'date': '1991', 'count': 1, 'keywords': 'troposphere'}, {'date': '1991', 'keywords': 'photochemistry', 'count': 1}, {'date': '1991', 'keywords': 'clouds', 'count': 1}, {'date': '1991', 'keywords': 'ozone', 'count': 1}, {'date': '1992', 'count': 1, 'keywords': 'crystal growth'}, {'date': '1992', 'keywords': 'nucleation', 'count': 1}, {'date': '1992', 'keywords': 'supercooling', 'count': 1}, {'date': '1995', 'count': 1, 'keywords': 'animal waste'}, {'date': '1995', 'keywords': 'volatilization of aliphatic amines', 'count': 1}, {'date': '1995', 'keywords': 'atmospheric chemistry of methylamines', 'count': 1}, {'date': '1995', 'keywords': 'global n2o', 'count': 1}, {'date': '1995', 'keywords': 'hcn budgets', 'count': 1}, {'date': '1995', 'keywords': 'model', 'count': 1}, {'date': '1995', 'keywords': 'orographic cloud', 'count': 1}, {'date': '1995', 'keywords': 'sulfur', 'count': 1}, {'date': '1995', 'keywords': 'nitrogen oxides', 'count': 1}, {'date': '1995', 'keywords': 'heterogeneous oxidation', 'count': 1}, {'date': '1995', 'keywords': 'iron catalysis', 'count': 1}, {'date': '1995', 'keywords': 'henrys law', 'count': 1}, {'date': '1995', 'keywords': 'droplet size spectrum', 'count': 1}, {'date': '1994', 'count': 1, 'keywords': 'global model'}, {'date': '1994', 'keywords': 'emission inventory', 'count': 1}, {'date': '1994', 'keywords': 'ammonia', 'count': 1}, {'date': '1994', 'keywords': 'ammonium', 'count': 1}, {'date': '1994', 'keywords': 'nitrous oxide', 'count': 1}, {'date': '1994', 'keywords': 'acidity', 'count': 1}, {'date': '1994', 'keywords': 'canopy compensation point', 'count': 1}, {'date': '1997', 'count': 1, 'keywords': 'balloon-borne sensors'}, {'date': '1997', 'keywords': 'humidity', 'count': 1}, {'date': '1997', 'keywords': 'tracer transport', 'count': 1}, {'date': '1997', 'keywords': 'tropical convection', 'count': 1}, {'date': '1996', 'count': 1, 'keywords': 'atmospheric chemistry'}, {'date': '1996', 'keywords': 'nobel lecture', 'count': 1}, {'date': '1996', 'keywords': 'ozone', 'count': 1}, {'date': '1996', 'keywords': 'animal manure', 'count': 1}, {'date': '1996', 'keywords': 'nitrous oxide release', 'count': 1}, {'date': '1996', 'keywords': 'methane release', 'count': 1}, {'date': '1996', 'keywords': 'agricultural nitrogen budget', 'count': 1}, {'date': '1996', 'keywords': 'tropospheric methane', 'count': 1}, {'date': '1996', 'keywords': 'ch4 emissions', 'count': 1}, {'date': '1996', 'keywords': 'natural gas', 'count': 1}, {'date': '1996', 'keywords': 'tracers', 'count': 1}, {'date': '1999', 'count': 2, 'keywords': 'ozone'}, {'date': '1999', 'keywords': 'co', 'count': 1}, {'date': '1999', 'keywords': 'biomass burning', 'count': 1}, {'date': '1999', 'keywords': 'tropical savannah', 'count': 1}, {'date': '1999', 'keywords': 'ozone production ratio', 'count': 1}, {'date': '1999', 'keywords': 'upper stratosphere', 'count': 1}, {'date': '1999', 'keywords': 'ozone budget', 'count': 1}, {'date': '1999', 'keywords': 'ozone deficit problem', 'count': 1}, {'date': '1999', 'keywords': 'haloe', 'count': 1}, {'date': '1999', 'keywords': 'convection', 'count': 1}, {'date': '1999', 'keywords': 'equatorial pacific', 'count': 1}, {'date': '1999', 'keywords': 'global modelling', 'count': 1}, {'date': '1999', 'keywords': 'tropics', 'count': 1}, {'date': '1999', 'keywords': 'aerosol', 'count': 1}, {'date': '1999', 'keywords': 'iodine chemistry', 'count': 1}, {'date': '1999', 'keywords': 'halogen chemistry', 'count': 1}, {'date': '1999', 'keywords': 'marine boundary layer', 'count': 1}, {'date': '1999', 'keywords': 'modeling', 'count': 1}, {'date': '1999', 'keywords': 'ozone loss', 'count': 1}, {'date': '1999', 'keywords': 'sea salt', 'count': 1}, {'date': '1999', 'keywords': 'chemical ozone loss (arctic vortex 1995-96', 'count': 1}, {'date': '1999', 'keywords': 'halogen chemistry)', 'count': 1}, {'date': '1998', 'count': 1, 'keywords': 'atmospheric composition and structure'}, {'date': '1998', 'keywords': 'middle atm ...

# %%
# Create the CSV File.

import csv
keys = ['date','keywords','count']
f = open('Excel-CrutzenPJ.csv', 'wb')
dict_writer = csv.DictWriter(f, keys)
dict_writer.writer.writerow(keys)
dict_writer.writerows(main_list)
